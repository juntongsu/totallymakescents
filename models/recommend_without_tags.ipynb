# %% [markdown]
# This file generates data with notes, accords and reviews classified into "positive" and "negative". It also includes a section that recommends perfume with a Sentence-BERT model, using the aforementioned data.  **This version does not generate tags.**

# %% [markdown]
# # Check Data Existence

# %%
import os
import pandas as pd
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load data with "classify review" columns

combined_df_path = "/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/combined_df_classify_reviews.csv"

if os.path.exists(combined_df_path):
    print("Loading existing combined_df...\nSkip to Recommeded Perfumes")
    combined_df_classify_reviews = pd.read_csv(combined_df_path)
else:
    print("No combined_df, needs to processing raw data")
# Out:
# Loading existing combined_df...
# Skip to Recommeded Perfumes

# %% [markdown]
# # Load Data (Without Reviews)

# %%
# get perfume data without reviews

file_path = '/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/fra_standard.csv'
with open(file_path, encoding='latin1') as f:
    reader = csv.reader(f)
    for i, row in enumerate(reader):
        print(f"Line {i+1}: {row}")
        if i >= 9:  # print first 10 lines
            break
# Out:
# Line 1: ['', 'url', 'Perfume', 'Brand', 'Rating Count', 'Top', 'Middle', 'Base', 'mainaccord1', 'mainaccord2', 'mainaccord3', 'mainaccord4', 'mainaccord5']
# Line 2: ['0', 'https://www.fragrantica.com/perfume/xerjoff/accento-overdose-pride-edition-74630.html', 'Accento Overdose Pride Edition', 'Xerjoff', '201', 'fruity notes, aldehydes, green notes', 'bulgarian rose, egyptian jasmine, lily-of-the-valley', 'eucalyptus, pine', 'rose', 'woody', 'fruity', 'aromatic', 'floral']
# Line 3: ['1', 'https://www.fragrantica.com/perfume/jean-paul-gaultier/classique-pride-2024-90394.html', 'Classique Pride 2024', 'Jean Paul Gaultier', '70', 'yuzu, citruses', 'orange blossom, neroli', 'musk, blonde woods', 'citrus', 'white floral', 'sweet', 'fresh', 'musky']
# Line 4: ['2', 'https://www.fragrantica.com/perfume/jean-paul-gaultier/classique-pride-2023-81775.html', 'Classique Pride 2023', 'Jean Paul Gaultier', '285', 'blood orange, yuzu', 'neroli, orange blossom', 'musk, white woods', 'citrus', 'white floral', 'sweet', 'fresh spicy', 'musky']
# Line 5: ['3', 'https://www.fragrantica.com/perfume/bruno-banani/pride-edition-man-55514.html', 'Pride Edition Man', 'Bruno Banani', '59', 'guarana, grapefruit, red apple', 'walnut, lavender, guava', 'vetiver, benzoin, amber', 'fruity', 'nutty', 'woody', 'tropical', '']
# Line 6: ['4', 'https://www.fragrantica.com/perfume/jean-paul-gaultier/le-male-pride-collector-60765.html', 'Le MÃ¢le Pride Collector', 'Jean Paul Gaultier', '632', 'mint, lavender, cardamom, artemisia, bergamot', 'caraway, cinnamon, orange blossom', 'vanilla, sandalwood, amber, cedar, tonka bean', 'aromatic', 'warm spicy', 'fresh spicy', 'cinnamon', 'vanilla']
# Line 7: ['5', 'https://www.fragrantica.com/perfume/jean-paul-gaultier/le-male-pride-2023-81774.html', 'Le Male Pride 2023', 'Jean Paul Gaultier', '531', 'yuzu, blood orange', 'neroli, orange blossom', 'musk, white woods', 'citrus', 'white floral', 'sweet', 'fresh spicy', 'green']
# Line 8: ['6', 'https://www.fragrantica.com/perfume/jean-paul-gaultier/le-male-pride-2024-90393.html', 'Le Male Pride 2024', 'Jean Paul Gaultier', '285', 'citruses, yuzu', 'neroli, orange blossom', 'woodsy notes, musk', 'white floral', 'citrus', 'fresh', 'soapy', '']
# Line 9: ['7', 'https://www.fragrantica.com/perfume/ralph-lauren/polo-red-pride-edition-62728.html', 'Polo Red Pride Edition', 'Ralph Lauren', '107', 'cranberry, pink grapefruit, citron', 'clary sage, lavender, saffron', 'amberwood, brazilian redwood, coffee', 'woody', 'amber', 'citrus', 'warm spicy', 'aromatic']
# Line 10: ['8', 'https://www.fragrantica.com/perfume/ralph-lauren/ralph-pride-edition-62727.html', 'Ralph Pride Edition', 'Ralph Lauren', '50', 'tangerine, green apple, freesia', 'magnolia, lime (linden blossom), osmanthus', 'musk, white iris', 'citrus', 'fruity', 'floral', 'sweet', 'green']

# %%
df = pd.read_csv(
    file_path,
    sep=',', # specify correct separator
    encoding='latin1',
    low_memory=False
)

# %% [markdown]
# # Load Data (With Reviews)

# %%
# get perfume data with reviews

file_path = '/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/perfumes_table.csv'
with open(file_path, encoding='latin1') as f:
    reader = csv.reader(f)
    for i, row in enumerate(reader):
        print(f"Line {i+1}: {row}")
        if i >= 9:  # print first 10 lines
            break
# Out:
# Line 1: ['rating', 'notes', 'designer', 'reviews', 'description', 'url', 'title']
# Line 2: ['5.0', "['Vanila', 'Madagascar Vanilla', 'Vanilla Absolute']", 'fiorucci perfumes and colognes', '[]', 'Vanilla Scent by Fiorucci is a Amber Vanilla fragrance for women and men. Vanilla Scent was launched in 1961. Top note is Vanila; middle note is Madagascar Vanilla; base note is Vanilla Absolute.', 'https://www.fragrantica.com/perfume/Fiorucci/Vanilla-Scent-34262.html', 'Vanilla Scent Fiorucci for women and men']
# Line 3: ['4.22', "['Mint', 'Lavender', 'Nutmeg', 'elemi', 'Cypress', 'Sandalwood', 'Saffron', 'Cypriol Oil or Nagarmotha', 'Amber', 'Patchouli', 'Precious Woods', 'Musk']", 'maiora parfum perfumes and colognes', '[]', 'Shady by Maiora Parfum is a fragrance for women and men. Shady was launched in 2019. The nose behind this fragrance is Antonio Gigli. Top notes are Mint, Lavender, Nutmeg and elemi; middle notes are Cypress, Sandalwood, Saffron and Cypriol Oil or Nagarmotha; base notes are Amber, Patchouli, Precious Woods and Musk.', 'https://www.fragrantica.com/perfume/Maiora-Parfum/Shady-75400.html', 'Shady Maiora Parfum for women and men']
# Line 4: ['3.81', "['Neroli', 'Vetiver', 'Basil', 'Fig']", 'guerlain perfumes and colognes', '["the opening is too sharp that it reminds me of a laundry detergent, but as it settles down, the shaprness goes away and i get to sense the fresh, orangey, soft, floral qualities of the neroli, which is the main event of this scent. It also has a green, herbaceous tone in it, which is probably courtesy of the basil. The fig note is also there underneath giving it a bit of creaminess, which made me realize that neroli and fig could make a really interesting and pleasant combination. I unfortunately haven\'t smelled vetiver in isolation, hence I can\'t comment on its contribution. \\nOverall, this is a really pleasant, likable and easy to wear scent that one can wear on a daily basis. It\'s my approachable clean girl fragrance, lol...i really like it though.", \'It has a screechy opening that actually induces headaches. The dry down though is sweet - it could be the fig.\', \'I agree with the comment below.\\nThis one is really challenging. Way too sharp and green while the white floral aspect is subdued.\\nAlso this is nothing like Neroli Amara by VCA. Surely, they both have as a main note the neroli, but I find Nerolia Vetiver more complex and challenging because of the green and sharp quality it has.\\nNeroli Amara is fresh and citrusy, easy-going and more rounded scent. \\nFor me Nerolia Vetiver is not a safe blind buy.\', \'Oooh this is a tough one. I recognize it is beautiful because I can discern natural notes of neroli, vetiver and basil. But as a fragrance, it is not for me. I find it really sharp and masculine-leaning in the opening. It reminds me a lot of 4711 Eau De Cologne, but stronger. The drydown is more mellow, but soapy.\', "Vetiver and neroli are beautiful scents. If the usual vetiver scents are too prickly for you, you should try this Guerlain. Gentle, slightly soapy, unisex and a little creamy. It actually reminds me a little of Creed\'s Vetiver. This perfume is a little insider tip.", \'I prefer this to the Forte or Harvest version, as those contain orange blossom, which Iâ\x80\x99m not a fan of, and make the neroli seem sweeter and less fresh. This has phenomenal performance, good longevity and projection for an EDT so I bought a 125 ml on sale. The fig in this smells like fig nectar.\', "I love this fresh green floral that is not sweet or cloying. I really enjoy the sharpness of the top neroli note, and find that it lasts a surprisingly long time for a this type of scent, or any Aqua Allegoria I\'ve tried. Every time I wear it I ask myself why I don\'t wear it more often!", \'I have this and each time I wear it I question if I like it, but then get addicted to sniffing it throughout the day. It smells clean, strongly of citrus, though it is a bit â\x80\x9cdryâ\x80\x9d of a smell (possibly the vetiver), with some inoffensive (quite pretty actually) florals and slight sweetness rounding things off. There is something bitter (if you could smell bitter!) in the opening. Maybe thatâ\x80\x99s why I always question whether I like it or not. Anyway, this isnâ\x80\x99t a perfume I choose to wear often, but Iâ\x80\x99m glad to have it, because it is very enjoyable in the summer. It smells very realistic, not fake or cloying. I also own 2 other Aqua Allegoria and I get the best performance and silage out of this one, about 5 hours on skin, 8 on clothing. I consider that very good for such a light, fresh, citrusy eau de toilette. Perfectly enjoyable, perfectly unisex.\', "There are some very strange \'noses\' and interpretations on this below.\\nI know we all have different noses, brains and body chemistry but come on, some of you are surely not smelling the same fragrance.\\nIt\'s these wildly different and bizarre reviews that make this review section all pretty pointless. \\nCleaning product? Pledge? Same vetiver as Guerlain Vetiver? FFS.", \'The only one in the entire Aqua Allegoria range that actually has a hint of swee ...
# Line 5: ['4.0', "['Orange Blossom', 'Star Anise', 'Pear', 'Rose', 'Mandarin Orange', 'Ylang-Ylang', 'Iris', 'Orchid', 'Plum', 'Ginger', 'Amber', 'Musk', 'Vanilla']", 'jean paul gaultier perfumes and colognes', "['I must ask. What part of the country did this one show up in? I have not seen it in department stores in San Antonio, TX. I must be doing something wrong...advice?']", 'Classique Love Actually by Jean Paul Gaultier is a Amber Floral fragrance for women. Classique Love Actually was launched in 2011. The nose behind this fragrance is Jacques Cavallier. Top notes are Orange Blossom, Star Anise, Pear, Rose and Mandarin Orange; middle notes are Ylang-Ylang, Iris, Orchid, Plum and Ginger; base notes are Amber, Musk and Vanilla.', 'https://www.fragrantica.com/perfume/Jean-Paul-Gaultier/Classique-Love-Actually-11356.html', 'Classique Love Actually Jean Paul Gaultier for women']
# Line 6: ['4.22', "['Petitgrain', 'Orange', 'Bergamot', 'Lemon Verbena', 'Lime', 'Grapefruit', 'Lavender', 'African Orange Flower', 'Jasmine', 'Carnation', 'Geranium', 'oak moss']", 'santa maria novella perfumes and colognes', '[\'Beautiful and uplifting. Initially fresh and exuberant, after an hour you are left with ethereal soft green notes.\\nTruly a beautiful orange blossom fragrance, just does not last long at all (about 2 hours)...\', "Happiness in a bottle. The optimistic zing! of orange flower. Very natural and uplifting, just a little green, and strictly for hot summer weather. Ideal for spritzing on before strolling about in Italian sunshine. Works as a cologne â\x80\x94 after 90 minutes I\'m left with just lemon verbena on my skin â\x80\x94 so expect to reapply or spray on clothing to stretch it out.", \'Fleeting, linear, clean sweet orange blossoms. Sort of like walking down the street and picking an orange blossom, inhaling deeply then tossing it to the dirt. I have a bespoke perfume oil with notes of sandalwood and aquozone that pairs nicely with this sample. I will not be buying a full size bottle.\', \'...     \\nFaint, elegant, clean. \\nA forgettable scent that an ordinary person might remember you for.     \\n[zagara]\', \'Zing! An ultra-fresh blast of orange blossom that is certain to wake you up! As it mellows a bit, Zagara becomes soapy and innocent, and never lets you forget that the orange blossom is large and in charge.  \\nAs nearly every other reviewer here mentions, the longevity is flat-out nonexistent. I am able to come to terms with it as this fragrance represents a very special visit to the Santa Maria Novella apothecary in Florence in the height of summer. I splashed it proudly and felt quite lovely, thank you. Despite the ultra-quick dissipation, it absolutely harnesses the imagination (which all good fragrances should do, yes?).  \\nDespite being far from perfect, Zagara has earned its coveted feature on my dresser this season.\', "A fine, old-fashioned Italian soap. Not sure I\'d want to wear this, though.", "Zagara smells exactly like floral orange blossom/Neroli sunscreen, but it also smells natural and pure. Anyone searching for a beachy orange blossom scent should not overlook Zagara. \\nIt\'s not too sweet nor too bitter, and it is fresh smelling without indoles, but still true to the scent of the real blooming tree. My mom said it also smells like the lemon blossoms of her hometown. \\nThe base is smooth and soapy. Zagara is such a joyous, light-filled fragrance. My favorite orange blossom-centered fragrance so far.", "Why do the pretty ones always break your heart? \\nThey love you and leave you and take all the things you needed so bad... \\nI\'ve had my eye on this for quite some time and finally found a sample available on ebay. I had a feeling it would be good, and it didn\'t disappoint. Ever since the discontinuation of LUSH Orange Blossom I have searched in vain for something to match it. Time and again I have ordered a sample of something promising only to be served up something bland or too bitter/sour. Tom Ford Neroli Portofino for example is so bitter and pungent I had to leave the room trying to get away from myself! \\nSMN had a touch of the bitterness but it is closest to the LUSH scent I have found. I thought I had found THE ONE Orange Blossom...until 30 minutes later I could smell nothing. Where did it go? I sprayed it on again and same thing happened. What a letdown. I know it is cologne but at $125 for 3.3 ounces, I think it should last longer than 30 minutes. I would even be okay with 3 hour longevity. \\nIt IS very, very good; not quite as good as LUSH Orange Blossom (which was less expensive PERFUME and lasted all day) but it coulda been a contender if not for such poor longevity.", \'A very bright, piercing, and happy orange blossom! Not at all *orange*, but the flower, similar to Neroli essential oil, on a soapy base. Agree that this has very poor lasting power.\' ...
# Line 7: ['3.66', "['Bamboo', 'Violet', 'Water Hyacinth', 'Kiwi', 'Ivy', 'Orchid', 'Lily', 'Freesia', 'Jasmine', 'Rose', 'White Musk', 'Sandalwood', 'Plum']", 'oriflame perfumes and colognes', '[\'DO starts airy and fresh proceeding quickly to a feminine floral with some elegance. The base is balanced between a clean soapy white musk and warm fruity woods. A good everyday perfume with mediocre performance. Lovely yes, but â\x80\x9cdivineâ\x80\x9d it is not.\', \'as other reviewers said, divine smells like your natural scent stepping out of the shower, which is lovely for what it is. Great for summer days.\', \'great for summer but too soapy.\', "It smells somewhat dry, perhaps due to violet, musk and wood note. Dry, yet in same time soapy and watery. Nothing spectacular, clean, floral, dry-ish ,wood-y, inoffensive, feminine, up lifting. Slightly fruity perhaps from kivi note. Not sure why name say Divine, rather I can imagine woman\'s apartment with clean wood furniture in background. Somewhat unique, maybe because it\'s bit old fashion scent since this is from 2000\'s, but it\'s inoffensive, still interesting and wearable. At first it smells quite terrible, but wait some 10 minutes for it to develop. More time passes more softer and cheap fruity-floral it gets. Silage and longevity is quite sad as with most of these types of perfumes.", \'A cheap, alcoholic, mess with no silage. Bad.\', "A pleasant fresh smell just like after shower. I really love Divine fresh and clean smell, but sadly it\'s only last 2 hours on my skin, while if it\'s on clothes could last about 4 hours. I like to wear this perfume right after shower in the morning, it gives a feeling like you enter a spring garden full of white flowers. But, yeah... it\'s not long lasting, you should respray it again after 2 or 3 hours to keep the silage there. I like the bottle, kinda sexy curve, but not so travel friendly as it is quite tall bottle for such a tiny make up pouch. Overall, this perfume is something I can wear everyday during the day time, or before going to sleep. But it\'s less prominent for an evening special occasion. Repurchase? Of course, as I wear this quite often for daily use.", "This is a very weak, watery scent. A few minutes after initially applying it to my wrists, I could barely smell it on my skin, but the sillage is better - I get wafts of it every now and again, with different notes emerging as it develops. \\nDivine is a simple, clean floral scent with a hint of fruity sweetness. Fresh, green, watery white florals make up Divine, with a squeeze of natural fruit juice. Freesia is the most prominent note to my nose, and water hyacinth (a note I haven\'t smelled before, but judging from its description) is a close second. It is aquatic, slightly aromatic and green. Bamboo adds a very light, green woodiness, complementing the other notes nicely. The drydown is musky as the aquatic florals fade. I do get a hint of plum in the base too. Longevity is short-lived and sillage is intimate-to-moderate while it lasts. \\nLinear, fresh and extremely subtle, this scent has no sharp edges (unlike, for example, D&G Light Blue). Discreet and softly feminine, it would likely suit people who don\'t like strong scent. For summer days. Too weak for my taste, but not bad. 2/5.", "It\'s such a clean, sophisticated floral scent. At first, it can come off as a little bit strong but in the dry down, it\'s very pleasant, sensual, and cozy.", \'This is so watered-down. Simple floral smell imo. Not overly sweet. Not overly anything. Just light. Non-offensive, turns into a skin scent fast. Takes quite a bit for the perfume alcohol smell to go away. Good for the workplace if you work somewhere in fast food or office jobs, idkkk... ð\x9f¤·ð\x9f\x8f»\', "For years and yeras now, I purchase it and repurchase it and i have a spare bottle on my shelf,too.\\nElegant, feminine and not repeated.\\nI don\'t remember that i smelled a similar fragrance, That\'s why I appreciate it  ...
# Line 8: ['', "['Lemon', 'Cardamom', 'Lily-of-the-Valley', 'Anise', 'Lavender', 'Geranium', 'Cedar', 'Vanilla', 'Musk']", 'jequiti perfumes and colognes', '[]', 'Tiago Abravanel Mania by Jequiti is a Woody Aromatic fragrance for men. Tiago Abravanel Mania was launched in 2018. The nose behind this fragrance is Hernan FÃ\xadgoli. Top notes are Lemon and Cardamom; middle notes are Lily-of-the-Valley, Anise, Lavender and Geranium; base notes are Cedar, Vanilla and Musk.', 'https://www.fragrantica.com/perfume/Jequiti/Tiago-Abravanel-Mania-75382.html', 'Tiago Abravanel Mania Jequiti for men']
# Line 9: ['3.74', "['Cherry', 'Mandarin Orange', 'Datura', 'Ylang-Ylang', 'Almond', 'Biscuit', 'Musk', 'Cedar']", 'panouge perfumes and colognes', "['Not sure what it is but this smells like a wardrobe moth repellent from the 90s with a pee note... Not my cup of tea at all, glad I only bought a decant.', 'RiddlesKitty review is so accurate!\\nI was expecting a sweet, cherry like biscotti type scent but thereâ\x80\x99s only a grain of sugar in this. You get the datura and itâ\x80\x99s quite prominent. It smells like the white flowers that grows on tobacco plants. Itâ\x80\x99s quite narcotic. \\nThereâ\x80\x99s a thick biscuit dough mixed with a slight medicinal vibe to it.\\nBut still really smooth and well balanced so good craftsmanship here and definitely a unique fragrance.\\nItâ\x80\x99s not my style of perfume but if itâ\x80\x99s yours you will enjoy it as it is very well made and extremely unique.\\nIt lasts and projection is moderate.', 'Waxy, creamy white floral. Thick, dense, with a bready/doughy bite. Hint of something fresh and green. Faint sweetness on drydown.', 'This might be the best perfume in the world. Realistic White Flowers a hint of biscuit. Genius', 'What I do enjoy in those Panouge scent is the silky airy note that fully express itself on my skin. Itâ\x80\x99s palpable and addictive. In DA, it makes the cherry sweet and light in the same time, more cosmetic than eatable. Then comes the dark princess, datura is not such an easy likable theme, but here I find it polite enough to appreciate its expressive presence, supported by almond biscotti just to die for.\\nI imagine a white dressed young queen, powerful, obstinate and fragile, a warrior with velvet hands, able to lead without raising her voice.', 'I found this fragrance offensive. I guess I am not a fan of cherry almond biscuits or poisonous flowers. On paper sounds sexy - in real life not so much.', 'Beautiful fragrance.\\nSomehow reminds of La Religieuse from Serge Lutens but you get datura flower instead of jasmin.\\nAlso gourmand because of the biscuit note inside.\\nElegant, comfy and delicious at the same time.Best for cooler weather.Performance is very good.\\nOut of all 4 from this collection, i would say this is best suited for winter, especially Christmas time.', 'What I do enjoy in those Panouge scent is the silky airy note that fully express itself on my skin. Itâ\x80\x99s palpable and addictive. In DA, it makes the cherry sweet and light in the same time, more cosmetic than eatable. Then comes the dark princess, datura is not such an easy likable theme, but here I find it polite enough to appreciate its expressive presence, supported by almond biscotti just to die for.\\nI imagine a white dressed young queen, powerful, obstinate and fragile, a warrior with velvet hands, able to lead without raising her voice.', 'I found this fragrance offensive. I guess I am not a fan of cherry almond biscuits or poisonous flowers. On paper sounds sexy - in real life not so much.', 'Not sure what it is but this smells like a wardrobe moth repellent from the 90s with a pee note... Not my cup of tea at all, glad I only bought a decant.']", 'Datura Amaretti by Panouge is a Amber Floral fragrance for women and men. Datura Amaretti was launched in 2021. Datura Amaretti was created by Patrice Revillard and Marie Schnirer. Top notes are Cherry and Mandarin Orange; middle notes are Datura and Ylang-Ylang; base notes are Almond, Biscuit, Musk and Cedar.', 'https://www.fragrantica.com/perfume/Panouge/Datura-Amaretti-57365.html', 'Datura Amaretti Panouge for women and men']
# Line 10: ['2.33', "['Mandarin Orange', 'Freesia', 'Orange Blossom', 'Pear', 'Peony', 'Sandalwood', 'Heliotrope', 'Raspberry']", 'franck olivier perfumes and colognes', "['Smells like a multisex version of Intimately Yours Women by David Beckham take out the sickly sweet almond from that and replace with powdery rosy orange. The sandalwood stops it being too sickly and floral. Nice. Not so keen on the bottle as it appears like it is a infants product rather than an adult multisex EDT. Longevity and silage are average. Tiny bottle. Youthful.', 'Smells like a multisex version of Intimately Yours Women by David Beckham take out the sickly sweet almond from that and replace with powdery rosy orange. The sandalwood stops it being too sickly and floral. Nice. Not so keen on the bottle as it appears like it is a infants product rather than an adult multisex EDT. Longevity and silage are average. Tiny bottle. Youthful.']", 'Baby Boy by Franck Olivier is a Citrus fragrance for men. This is a new fragrance. Baby Boy was launched in 2022. Top notes are Mandarin Orange and Freesia; middle notes are Orange Blossom, Pear and Peony; base notes are Sandalwood, Heliotrope and Raspberry.', 'https://www.fragrantica.com/perfume/Franck-Olivier/Baby-Boy-77143.html', 'Baby Boy Franck Olivier for men']

# %%
df_review = pd.read_csv(
    file_path,
    sep=',',            # specify correct separator
    encoding='latin1',
    low_memory=False
)

# %% [markdown]
# # Merge Data

# %%
# standardize URLs
df['url'] = df['url'].str.strip().str.lower().str.rstrip('/')
df_review['url'] = df_review['url'].str.strip().str.lower().str.rstrip('/')

# drop NaNs, empty strings, and whitespace-only reviews
df_review = df_review.dropna(subset=['reviews']).copy()
df_review['reviews'] = df_review['reviews'].astype(str).str.strip()
df_review = df_review[df_review['reviews'] != '']
df_review = df_review[df_review['reviews'] != '[]']

# group by URL and join reviews
agg_reviews = df_review.groupby('url')['reviews'].apply(','.join).reset_index()

# merge inner with notes
combined_df = pd.merge(df, agg_reviews, on='url', how='inner')

# %%
print(combined_df.columns)
print(combined_df.shape)
combined_df.head()
# Out:
# Index(['Unnamed: 0', 'url', 'Perfume', 'Brand', 'Rating Count', 'Top',
#        'Middle', 'Base', 'mainaccord1', 'mainaccord2', 'mainaccord3',
#        'mainaccord4', 'mainaccord5', 'reviews'],
#       dtype='object')
# (21950, 14)
#    Unnamed: 0                                                url  \
# 0           0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1           2  https://www.fragrantica.com/perfume/jean-paul-...
# 2           4  https://www.fragrantica.com/perfume/jean-paul-...
# 3           5  https://www.fragrantica.com/perfume/jean-paul-...
# 4           7  https://www.fragrantica.com/perfume/ralph-laur...
#
#                           Perfume               Brand  Rating Count  \
# 0  Accento Overdose Pride Edition             Xerjoff           201
# 1            Classique Pride 2023  Jean Paul Gaultier           285
# 2        Le MÃ¢le Pride Collector  Jean Paul Gaultier           632
# 3              Le Male Pride 2023  Jean Paul Gaultier           531
# 4          Polo Red Pride Edition        Ralph Lauren           107
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                             blood orange, yuzu
# 2  mint, lavender, cardamom, artemisia, bergamot
# 3                             yuzu, blood orange
# 4             cranberry, pink grapefruit, citron
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             neroli, orange blossom
# 2                  caraway, cinnamon, orange blossom
# 3                             neroli, orange blossom
# 4                      clary sage, lavender, saffron
#
#                                             Base mainaccord1   mainaccord2  \
# 0                               eucalyptus, pine        rose         woody
# 1                              musk, white woods      citrus  white floral
# 2  vanilla, sandalwood, amber, cedar, tonka bean    aromatic    warm spicy
# 3                              musk, white woods      citrus  white floral
# 4           amberwood, brazilian redwood, coffee       woody         amber
#
#    mainaccord3  mainaccord4 mainaccord5  \
# 0       fruity     aromatic      floral
# 1        sweet  fresh spicy       musky
# 2  fresh spicy     cinnamon     vanilla
# 3        sweet  fresh spicy       green
# 4       citrus   warm spicy    aromatic
#
#                                              reviews
# 0  ["I thought everybody was hating on this fragr...
# 1  ['Ummm... just like a honest review, ignoring ...
# 2  ['Lol to the reviewer below meâ¦no one cares,...
# 3  ['A bold fresh fragrance. Not recommended for ...
# 4  ["Tad bit sweeter than the other flankers, but...

# %%
print(combined_df['reviews'].iloc[0])
# Out:
# ["I thought everybody was hating on this fragrance for the homophobia, turns out its a cash grab where none of the profits go to any lgbtq organisation. don't buy", "Above and beyond super yikes totally gross pink-washing money grab. Next time give 50-100% of profits from the sales to LGBTQ+ orgs, AT THE VERY LEAST, especially since y'all are selling it at that price. Please Xerjoff, spare some change for the gays.", 'Embarrassing pink money cash grab, and during Pride month nonetheless! Xerjoff needs to show us where they\'re donating because simply saying they "support" the LGBTQ community is not enough...', 'FYI: When asked if some LGBTQ+ organization would receive part of earning from this bottle, the PR team of Xerjoff decided to copy paste to everyone a answer without answer, a way to try to save face and also try to confuse you. Gaslighting. But donât get confused, itâs just a money grab.', "The Fragcomm is on fire today because it does appear to me Xerjoff (a high end Italian niche House) has recently joined the growing list of perfume brands needlessly profiteering from a group of persons i.e LGBTQ. What is more saddening is the horrendous pricetag of â¬400+!\nGuys, I'm one person that respect the Community (both Fragcomm and LGBTQ). But what I'll brazenly speak against is the commercialization of someone's sexual identity and the fact that in most cases, the Big Brands fly the flag ingenuinely and ingenuously.\nThis. Must. Stop. \nIG: @mr_cornells", 'YIKES.', 'YIKES.', 'FYI: When asked if some LGBTQ+ organization would receive part of earning from this bottle, the PR team of Xerjoff decided to copy paste to everyone a answer without answer, a way to try to save face and also try to confuse you. Gaslighting. But donât get confused, itâs just a money grab.', "Above and beyond super yikes totally gross pink-washing money grab. Next time give 50-100% of profits from the sales to LGBTQ+ orgs, AT THE VERY LEAST, especially since y'all are selling it at that price. Please Xerjoff, spare some change for the gays."]

# %%
print(combined_df['reviews'].iloc[1])
# Out:
# ['Ummm... just like a honest review, ignoring all thisâ¦ other stuff. The blood orange scent is really strong, it gives off a bitter/tarte citrus opening (almost like grapefruit rind), but there not much else to it besides that. Honestly, I purchased thinking it was the original classique juice. Longevity is disappointing, about two-three hours. If you really like tarte bitter citrus this is great, and you should literally get it now, bc itâs discounted and a limited release.', '@AndyWarholsFavoriteWig:  \nAgreed, what the f is wrong with people. Like, I could imagine 12-year olds sitting and thinking that was hilarious... but I doubt they would be hanging out on fragrantica of all places, so we\'re talking probably adult men sitting and doing that shit. Like seriously, and I\'m an adult cis-gender straight(-ish) man saying this. \nI think some things that are immature, dark and not seen as "PC" can be very fun to joke about, but the thing with this is that it\'s just like... not funny. in any way.  \n@hexed: I get what you mean, but nah come on. Fragrances are universal, they\'re for the women and men, gay people and straight people, cis-gendered and trans (+NB) people, saying that perfumes and fragrances are gay is very reductive and becomes almost as childish as the people doing this shit in the first place.', 'Same as below, are the straighties here being so defensive simply because they chose a gay ass hobby aka collecting perfume, or....', "The usual âthis smells likeâ homophobic links to âAnalâ âSlutâ âScatâ âInexcusable Evilâ etc etc perfumes every year a JPG PRIDE edition comes out! You people are Pathetic! ð³ï¸â§ï¸ ð³ï¸ð  \nI've never understood why one of the big perfume houses hasn't taken discontinued popular fragrances and re-released them under a designer label (Jean Paul Gaultier doing a 'Homage' range for instance of old French perfumes)", "The usual âthis smells likeâ homophobic links to âAnalâ âSlutâ âScatâ âInexcusable Evilâ etc etc perfumes every year a JPG PRIDE edition comes out! You people are Pathetic! ð³ï¸â§ï¸ ð³ï¸ð  \nI've never understood why one of the big perfume houses hasn't taken discontinued popular fragrances and re-released them under a designer label (Jean Paul Gaultier doing a 'Homage' range for instance of old French perfumes)"]

# %% [markdown]
# # Classify Reviews

# %%
# Flatten the review column
flat_reviews = (
    combined_df['reviews']
    .explode()
    .reset_index()
    .rename(columns={"index": "idx", "reviews": "review_text"})
)

# %%
print(flat_reviews)
# Out:
#          idx                                        review_text
# 0          0  ["I thought everybody was hating on this fragr...
# 1          1  ['Ummm... just like a honest review, ignoring ...
# 2          2  ['Lol to the reviewer below meâ¦no one cares,...
# 3          3  ['A bold fresh fragrance. Not recommended for ...
# 4          4  ["Tad bit sweeter than the other flankers, but...
# ...      ...                                                ...
# 21945  21945  ['Cardamom bomb \n2014 batch still very very g...
# 21946  21946  ['This is an incredibly butch(or perhaps switc...
# 21947  21947  ['Khaox is a different perfume. Green, fresh, ...
# 21948  21948  ['Ive been wanting this fragrance ever since I...
# 21949  21949  ["This feels like Mad Men in a bottle, it's be...
#
# [21950 rows x 2 columns]

# %%
import torch
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
from tqdm import tqdm
import pandas as pd

tqdm.pandas()

tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
model.eval().to("cuda" if torch.cuda.is_available() else "cpu")

def classify_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    with torch.no_grad():
        logits = model(**inputs).logits

    predicted_class_id = logits.argmax().item()
    return model.config.id2label[predicted_class_id]

flat_reviews['sentiment'] = flat_reviews['review_text'].progress_apply(classify_sentiment)
flat_reviews['is_positive'] = flat_reviews['sentiment'].map({'POSITIVE': 1, 'NEGATIVE': 0})
# Out:
# 100%|██████████| 21950/21950 [30:29<00:00, 12.00it/s]

# %%
print(flat_reviews.columns)
print(flat_reviews)
# Out:
# Index(['idx', 'review_text', 'sentiment', 'is_positive'], dtype='object')
#          idx                                        review_text sentiment  \
# 0          0  ["I thought everybody was hating on this fragr...  NEGATIVE
# 1          1  ['Ummm... just like a honest review, ignoring ...  NEGATIVE
# 2          2  ['Lol to the reviewer below meâ¦no one cares,...  NEGATIVE
# 3          3  ['A bold fresh fragrance. Not recommended for ...  POSITIVE
# 4          4  ["Tad bit sweeter than the other flankers, but...  POSITIVE
# ...      ...                                                ...       ...
# 21945  21945  ['Cardamom bomb \n2014 batch still very very g...  POSITIVE
# 21946  21946  ['This is an incredibly butch(or perhaps switc...  POSITIVE
# 21947  21947  ['Khaox is a different perfume. Green, fresh, ...  POSITIVE
# 21948  21948  ['Ive been wanting this fragrance ever since I...  POSITIVE
# 21949  21949  ["This feels like Mad Men in a bottle, it's be...  POSITIVE
#
#        is_positive
# 0                0
# 1                0
# 2                0
# 3                1
# 4                1
# ...            ...
# 21945            1
# 21946            1
# 21947            1
# 21948            1
# 21949            1
#
# [21950 rows x 4 columns]

# %%
sentiment_summary = flat_reviews.groupby('idx').agg({
    'review_text': list,
    'sentiment': list,
    'is_positive': list
}).rename(columns={
    'review_text': 'review_texts',
    'sentiment': 'review_sentiments',
    'is_positive': 'review_labels'
})

# %%
# combined_df = combined_df.reset_index()
combined_df_classify_reviews = combined_df.merge(flat_reviews, left_index=True, right_on='idx', how='left')
combined_df_classify_reviews.drop(columns=['idx', 'review_text'], inplace=True)

# %%
combined_df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1           2  https://www.fragrantica.com/perfume/jean-paul-...
# 2           4  https://www.fragrantica.com/perfume/jean-paul-...
# 3           5  https://www.fragrantica.com/perfume/jean-paul-...
# 4           7  https://www.fragrantica.com/perfume/ralph-laur...
#
#                           Perfume               Brand  Rating Count  \
# 0  Accento Overdose Pride Edition             Xerjoff           201
# 1            Classique Pride 2023  Jean Paul Gaultier           285
# 2        Le MÃ¢le Pride Collector  Jean Paul Gaultier           632
# 3              Le Male Pride 2023  Jean Paul Gaultier           531
# 4          Polo Red Pride Edition        Ralph Lauren           107
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                             blood orange, yuzu
# 2  mint, lavender, cardamom, artemisia, bergamot
# 3                             yuzu, blood orange
# 4             cranberry, pink grapefruit, citron
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             neroli, orange blossom
# 2                  caraway, cinnamon, orange blossom
# 3                             neroli, orange blossom
# 4                      clary sage, lavender, saffron
#
#                                             Base mainaccord1   mainaccord2  \
# 0                               eucalyptus, pine        rose         woody
# 1                              musk, white woods      citrus  white floral
# 2  vanilla, sandalwood, amber, cedar, tonka bean    aromatic    warm spicy
# 3                              musk, white woods      citrus  white floral
# 4           amberwood, brazilian redwood, coffee       woody         amber
#
#    mainaccord3  mainaccord4 mainaccord5  \
# 0       fruity     aromatic      floral
# 1        sweet  fresh spicy       musky
# 2  fresh spicy     cinnamon     vanilla
# 3        sweet  fresh spicy       green
# 4       citrus   warm spicy    aromatic
#
#                                              reviews
# 0  ["I thought everybody was hating on this fragr...
# 1  ['Ummm... just like a honest review, ignoring ...
# 2  ['Lol to the reviewer below meâ¦no one cares,...
# 3  ['A bold fresh fragrance. Not recommended for ...
# 4  ["Tad bit sweeter than the other flankers, but...

# %%
# save combined data to avoid reruning next time
combined_df_classify_reviews.to_csv("/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/combined_df_classify_reviews.csv", index=False)

# %%
combined_df_path = "/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/combined_df.csv"

if os.path.exists(combined_df_path):
    print("Loading existing combined_df...\nSkip to Sentence-BERT")
    combined_df = pd.read_csv(combined_df_path)
else:
    print("No combined_df, needs to processing raw data")
# Out:
# Loading existing combined_df...
# Skip to Sentence-BERT

# %%
# combined_df has full_description column, but doesn't have sentiment and is_positive
combined_df.shape
# Out:
# (21950, 15)

# %%
combined_df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1           2  https://www.fragrantica.com/perfume/jean-paul-...
# 2           4  https://www.fragrantica.com/perfume/jean-paul-...
# 3           5  https://www.fragrantica.com/perfume/jean-paul-...
# 4           7  https://www.fragrantica.com/perfume/ralph-laur...
#
#                           Perfume               Brand  Rating Count  \
# 0  Accento Overdose Pride Edition             Xerjoff           201
# 1            Classique Pride 2023  Jean Paul Gaultier           285
# 2        Le MÃ¢le Pride Collector  Jean Paul Gaultier           632
# 3              Le Male Pride 2023  Jean Paul Gaultier           531
# 4          Polo Red Pride Edition        Ralph Lauren           107
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                             blood orange, yuzu
# 2  mint, lavender, cardamom, artemisia, bergamot
# 3                             yuzu, blood orange
# 4             cranberry, pink grapefruit, citron
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             neroli, orange blossom
# 2                  caraway, cinnamon, orange blossom
# 3                             neroli, orange blossom
# 4                      clary sage, lavender, saffron
#
#                                             Base mainaccord1   mainaccord2  \
# 0                               eucalyptus, pine        rose         woody
# 1                              musk, white woods      citrus  white floral
# 2  vanilla, sandalwood, amber, cedar, tonka bean    aromatic    warm spicy
# 3                              musk, white woods      citrus  white floral
# 4           amberwood, brazilian redwood, coffee       woody         amber
#
#    mainaccord3  mainaccord4 mainaccord5  \
# 0       fruity     aromatic      floral
# 1        sweet  fresh spicy       musky
# 2  fresh spicy     cinnamon     vanilla
# 3        sweet  fresh spicy       green
# 4       citrus   warm spicy    aromatic
#
#                                              reviews  \
# 0  I thought everybody was hating on this fragran...
# 1  ['Ummm... just like a honest review, ignoring ...
# 2  ['Lol to the reviewer below meâ¦no one cares,...
# 3  ['A bold fresh fragrance. Not recommended for ...
# 4  Tad bit sweeter than the other flankers, but a...
#
#                                     full_description
# 0  Top Notes: fruity notes, aldehydes, green note...
# 1  Top Notes: blood orange, yuzu. Middle Notes: n...
# 2  Top Notes: mint, lavender, cardamom, artemisia...
# 3  Top Notes: yuzu, blood orange. Middle Notes: n...
# 4  Top Notes: cranberry, pink grapefruit, citron....

# %%
# combined_df_classify_reviews has sentiment and is_positive columns, but doesn't have full_description column
combined_df_classify_reviews.shape
# Out:
# (21950, 16)

# %%
combined_df_classify_reviews.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1           2  https://www.fragrantica.com/perfume/jean-paul-...
# 2           4  https://www.fragrantica.com/perfume/jean-paul-...
# 3           5  https://www.fragrantica.com/perfume/jean-paul-...
# 4           7  https://www.fragrantica.com/perfume/ralph-laur...
#
#                           Perfume               Brand  Rating Count  \
# 0  Accento Overdose Pride Edition             Xerjoff           201
# 1            Classique Pride 2023  Jean Paul Gaultier           285
# 2        Le MÃ¢le Pride Collector  Jean Paul Gaultier           632
# 3              Le Male Pride 2023  Jean Paul Gaultier           531
# 4          Polo Red Pride Edition        Ralph Lauren           107
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                             blood orange, yuzu
# 2  mint, lavender, cardamom, artemisia, bergamot
# 3                             yuzu, blood orange
# 4             cranberry, pink grapefruit, citron
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             neroli, orange blossom
# 2                  caraway, cinnamon, orange blossom
# 3                             neroli, orange blossom
# 4                      clary sage, lavender, saffron
#
#                                             Base mainaccord1   mainaccord2  \
# 0                               eucalyptus, pine        rose         woody
# 1                              musk, white woods      citrus  white floral
# 2  vanilla, sandalwood, amber, cedar, tonka bean    aromatic    warm spicy
# 3                              musk, white woods      citrus  white floral
# 4           amberwood, brazilian redwood, coffee       woody         amber
#
#    mainaccord3  mainaccord4 mainaccord5  \
# 0       fruity     aromatic      floral
# 1        sweet  fresh spicy       musky
# 2  fresh spicy     cinnamon     vanilla
# 3        sweet  fresh spicy       green
# 4       citrus   warm spicy    aromatic
#
#                                              reviews sentiment  is_positive
# 0  ["I thought everybody was hating on this fragr...  NEGATIVE            0
# 1  ['Ummm... just like a honest review, ignoring ...  NEGATIVE            0
# 2  ['Lol to the reviewer below meâ¦no one cares,...  NEGATIVE            0
# 3  ['A bold fresh fragrance. Not recommended for ...  POSITIVE            1
# 4  ["Tad bit sweeter than the other flankers, but...  POSITIVE            1

# %%
# merge combined_df and combined_df_classify_reviews to have the data that
# has full_description, sentiment and is_positive columns
merged_df = pd.merge(
    combined_df_classify_reviews,
    combined_df[['url', 'Perfume', 'full_description']],
    on=['url', 'Perfume'],
    how='left'
)

# %%
merged_df.drop("full_description", axis=1, inplace=True)
merged_df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1           2  https://www.fragrantica.com/perfume/jean-paul-...
# 2           4  https://www.fragrantica.com/perfume/jean-paul-...
# 3           5  https://www.fragrantica.com/perfume/jean-paul-...
# 4           7  https://www.fragrantica.com/perfume/ralph-laur...
#
#                           Perfume               Brand  Rating Count  \
# 0  Accento Overdose Pride Edition             Xerjoff           201
# 1            Classique Pride 2023  Jean Paul Gaultier           285
# 2        Le MÃ¢le Pride Collector  Jean Paul Gaultier           632
# 3              Le Male Pride 2023  Jean Paul Gaultier           531
# 4          Polo Red Pride Edition        Ralph Lauren           107
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                             blood orange, yuzu
# 2  mint, lavender, cardamom, artemisia, bergamot
# 3                             yuzu, blood orange
# 4             cranberry, pink grapefruit, citron
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             neroli, orange blossom
# 2                  caraway, cinnamon, orange blossom
# 3                             neroli, orange blossom
# 4                      clary sage, lavender, saffron
#
#                                             Base mainaccord1   mainaccord2  \
# 0                               eucalyptus, pine        rose         woody
# 1                              musk, white woods      citrus  white floral
# 2  vanilla, sandalwood, amber, cedar, tonka bean    aromatic    warm spicy
# 3                              musk, white woods      citrus  white floral
# 4           amberwood, brazilian redwood, coffee       woody         amber
#
#    mainaccord3  mainaccord4 mainaccord5  \
# 0       fruity     aromatic      floral
# 1        sweet  fresh spicy       musky
# 2  fresh spicy     cinnamon     vanilla
# 3        sweet  fresh spicy       green
# 4       citrus   warm spicy    aromatic
#
#                                              reviews sentiment  is_positive
# 0  ["I thought everybody was hating on this fragr...  NEGATIVE            0
# 1  ['Ummm... just like a honest review, ignoring ...  NEGATIVE            0
# 2  ['Lol to the reviewer below meâ¦no one cares,...  NEGATIVE            0
# 3  ['A bold fresh fragrance. Not recommended for ...  POSITIVE            1
# 4  ["Tad bit sweeter than the other flankers, but...  POSITIVE            1

# %%
# construct a column with a full description so that BERT can understand

def build_full_description(row):
    # so that BERT can understand different fields

    top = row.get('Top', '')
    middle = row.get('Middle', '')
    base = row.get('Base', '')

    accords = ', '.join([
        str(row.get('mainaccord1', '')),
        str(row.get('mainaccord2', '')),
        str(row.get('mainaccord3', '')),
        str(row.get('mainaccord4', '')),
        str(row.get('mainaccord5', ''))
    ])

    reviews = row.get('reviews', '')

    description = (
        f"Top Notes: {top}. "
        f"Middle Notes: {middle}. "
        f"Base Notes: {base}. "
        f"Main Accords: {accords}. "
    )

    return description.strip()

merged_df['full_description'] = merged_df.apply(build_full_description, axis=1)

# %%
merged_df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1           2  https://www.fragrantica.com/perfume/jean-paul-...
# 2           4  https://www.fragrantica.com/perfume/jean-paul-...
# 3           5  https://www.fragrantica.com/perfume/jean-paul-...
# 4           7  https://www.fragrantica.com/perfume/ralph-laur...
#
#                           Perfume               Brand  Rating Count  \
# 0  Accento Overdose Pride Edition             Xerjoff           201
# 1            Classique Pride 2023  Jean Paul Gaultier           285
# 2        Le MÃ¢le Pride Collector  Jean Paul Gaultier           632
# 3              Le Male Pride 2023  Jean Paul Gaultier           531
# 4          Polo Red Pride Edition        Ralph Lauren           107
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                             blood orange, yuzu
# 2  mint, lavender, cardamom, artemisia, bergamot
# 3                             yuzu, blood orange
# 4             cranberry, pink grapefruit, citron
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             neroli, orange blossom
# 2                  caraway, cinnamon, orange blossom
# 3                             neroli, orange blossom
# 4                      clary sage, lavender, saffron
#
#                                             Base mainaccord1   mainaccord2  \
# 0                               eucalyptus, pine        rose         woody
# 1                              musk, white woods      citrus  white floral
# 2  vanilla, sandalwood, amber, cedar, tonka bean    aromatic    warm spicy
# 3                              musk, white woods      citrus  white floral
# 4           amberwood, brazilian redwood, coffee       woody         amber
#
#    mainaccord3  mainaccord4 mainaccord5  \
# 0       fruity     aromatic      floral
# 1        sweet  fresh spicy       musky
# 2  fresh spicy     cinnamon     vanilla
# 3        sweet  fresh spicy       green
# 4       citrus   warm spicy    aromatic
#
#                                              reviews sentiment  is_positive  \
# 0  ["I thought everybody was hating on this fragr...  NEGATIVE            0
# 1  ['Ummm... just like a honest review, ignoring ...  NEGATIVE            0
# 2  ['Lol to the reviewer below meâ¦no one cares,...  NEGATIVE            0
# 3  ['A bold fresh fragrance. Not recommended for ...  POSITIVE            1
# 4  ["Tad bit sweeter than the other flankers, but...  POSITIVE            1
#
#                                     full_description
# 0  Top Notes: fruity notes, aldehydes, green note...
# 1  Top Notes: blood orange, yuzu. Middle Notes: n...
# 2  Top Notes: mint, lavender, cardamom, artemisia...
# 3  Top Notes: yuzu, blood orange. Middle Notes: n...
# 4  Top Notes: cranberry, pink grapefruit, citron....

# %%
merged_df.iloc[0]['full_description']
# Out:
# 'Top Notes: fruity notes, aldehydes, green notes. Middle Notes: bulgarian rose, egyptian jasmine, lily-of-the-valley. Base Notes: eucalyptus, pine. Main Accords: rose, woody, fruity, aromatic, floral.'

# %%
# save combined data to avoid reruning next time
merged_df.to_csv("/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/combined_df_classify_reviews.csv", index=False)

# %% [markdown]
# # Recommend Perfumes with Classified Reviews

# %%
combined_df_classify_reviews.shape
# Out:
# (21950, 17)

# %%
combined_df_classify_reviews.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.fragrantica.com/perfume/xerjoff/ac...
# 1           2  https://www.fragrantica.com/perfume/jean-paul-...
# 2           4  https://www.fragrantica.com/perfume/jean-paul-...
# 3           5  https://www.fragrantica.com/perfume/jean-paul-...
# 4           7  https://www.fragrantica.com/perfume/ralph-laur...
#
#                           Perfume               Brand  Rating Count  \
# 0  Accento Overdose Pride Edition             Xerjoff           201
# 1            Classique Pride 2023  Jean Paul Gaultier           285
# 2        Le MÃ¢le Pride Collector  Jean Paul Gaultier           632
# 3              Le Male Pride 2023  Jean Paul Gaultier           531
# 4          Polo Red Pride Edition        Ralph Lauren           107
#
#                                              Top  \
# 0           fruity notes, aldehydes, green notes
# 1                             blood orange, yuzu
# 2  mint, lavender, cardamom, artemisia, bergamot
# 3                             yuzu, blood orange
# 4             cranberry, pink grapefruit, citron
#
#                                               Middle  \
# 0  bulgarian rose, egyptian jasmine, lily-of-the-...
# 1                             neroli, orange blossom
# 2                  caraway, cinnamon, orange blossom
# 3                             neroli, orange blossom
# 4                      clary sage, lavender, saffron
#
#                                             Base mainaccord1   mainaccord2  \
# 0                               eucalyptus, pine        rose         woody
# 1                              musk, white woods      citrus  white floral
# 2  vanilla, sandalwood, amber, cedar, tonka bean    aromatic    warm spicy
# 3                              musk, white woods      citrus  white floral
# 4           amberwood, brazilian redwood, coffee       woody         amber
#
#    mainaccord3  mainaccord4 mainaccord5  \
# 0       fruity     aromatic      floral
# 1        sweet  fresh spicy       musky
# 2  fresh spicy     cinnamon     vanilla
# 3        sweet  fresh spicy       green
# 4       citrus   warm spicy    aromatic
#
#                                              reviews sentiment  is_positive  \
# 0  ["I thought everybody was hating on this fragr...  NEGATIVE            0
# 1  ['Ummm... just like a honest review, ignoring ...  NEGATIVE            0
# 2  ['Lol to the reviewer below meâ¦no one cares,...  NEGATIVE            0
# 3  ['A bold fresh fragrance. Not recommended for ...  POSITIVE            1
# 4  ["Tad bit sweeter than the other flankers, but...  POSITIVE            1
#
#                                     full_description
# 0  Top Notes: fruity notes, aldehydes, green note...
# 1  Top Notes: blood orange, yuzu. Middle Notes: n...
# 2  Top Notes: mint, lavender, cardamom, artemisia...
# 3  Top Notes: yuzu, blood orange. Middle Notes: n...
# 4  Top Notes: cranberry, pink grapefruit, citron....

# %%
combined_df_classify_reviews.iloc[0]['full_description']
# Out:
# 'Top Notes: fruity notes, aldehydes, green notes. Middle Notes: bulgarian rose, egyptian jasmine, lily-of-the-valley. Base Notes: eucalyptus, pine. Main Accords: rose, woody, fruity, aromatic, floral.'

# %%
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (5.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.54.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.16.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.34.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.7.14)

# %%
from sentence_transformers import SentenceTransformer, util
import torch
import numpy as np
from tqdm import tqdm

# %%
s_model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# save the perfume_embeddings for later use.
# it takes some time to build the perfume_embeddings every time

import os
import torch

save_path = "/content/drive/MyDrive/Colab Notebooks/totallymakescents/perfume_embeddings.pt"

if not os.path.exists(save_path):
    descriptions = combined_df_classify_reviews["full_description"].tolist()
    weights = combined_df_classify_reviews["is_positive"].apply(lambda x: 1.0 if x == 1 else 0.3).tolist()
    embeddings = s_model.encode(
        descriptions,
        batch_size=32,
        convert_to_tensor=True,
        show_progress_bar=True
    )

    # Apply weights
    weights_tensor = torch.tensor(weights, device=embeddings.device).unsqueeze(1)
    weighted_embeddings = embeddings * weights_tensor

    torch.save(weighted_embeddings, save_path)
    print("Perfume embeddings with weighted reviews saved.")
else:
    perfume_embeddings = torch.load(save_path)
    print("Perfumes embeddings already exist — loading file.")
# Out:
# Perfumes embeddings already exist — loading file.

# %%
from sentence_transformers import util
import torch

def recommend_perfumes(user_query, top_k=5):
    query_embedding = s_model.encode(user_query, convert_to_tensor=True)
    scent_tensor = perfume_embeddings.to(query_embedding.device)

    similarities = util.cos_sim(query_embedding, scent_tensor)[0]
    top_results = torch.topk(similarities, k=top_k)

    print(f"\nUser Query: {user_query}\n")
    for score, idx in zip(top_results.values, top_results.indices):
        idx = idx.item() # convert Python tensor to int
        perfume = combined_df_classify_reviews.loc[idx]

        print(f"{perfume['Perfume']} by {perfume['Brand']} (Score: {score.item():.3f})")
        short_desc = (
          f"Top Notes: {perfume['Top']}. "
          f"Middle Notes: {perfume['Middle']}. "
          f"Base Notes: {perfume['Base']}.\n"
          f"Main Accords: {', '.join([str(perfume.get(f'mainaccord{i}', '')) for i in range(1, 6)])}."
          )

        print(f"{short_desc}\n")
        print(f"Sentiment: {perfume['sentiment']}")
        print(f"--------------------------------------------------------------------")

# %%
recommend_perfumes("I want something musky and warm with amber and vanilla", top_k=3)
# Out:
# User Query: I want something musky and warm with amber and vanilla
#
# Vanille Eau de Parfum by Laura Mercier (Score: 0.669)
# Top Notes: vanilla, vanilla orchid. Middle Notes: vanilla, heliotrope, daylily, musk. Base Notes: bourbon vanilla, sandalwood, amber.
# Main Accords: powdery, vanilla, amber, floral, musky.
#
# Sentiment: POSITIVE
# --------------------------------------------------------------------
# Midnight Journey by Burberry (Score: 0.654)
# Top Notes: ginger, black pepper, thyme. Middle Notes: guaiac wood, may rose, lavender. Base Notes: vanilla absolute, black amber, myrrh.
# Main Accords: amber, vanilla, warm spicy, woody, balsamic.
#
# Sentiment: POSITIVE
# --------------------------------------------------------------------
# Gold + by Commodity (Score: 0.652)
# Top Notes: amber, vanilla, sandalwood. Middle Notes: vanilla, iso e super. Base Notes: saffron, patchouli, nutmeg.
# Main Accords: woody, warm spicy, amber, vanilla, powdery.
#
# Sentiment: POSITIVE
# --------------------------------------------------------------------

# %%
recommend_perfumes("I want something fresh and floral with soft woody notes", top_k=3)
# Out:
# User Query: I want something fresh and floral with soft woody notes
#
# Autograph New York M by rks & Spencer (Score: 0.689)
# Top Notes: apricot, gardenia, bergamot. Middle Notes: woody notes, rose, jasmine. Base Notes: vanilla, musk, heliotrope, sandalwood.
# Main Accords: woody, powdery, vanilla, white floral, musky.
#
# Sentiment: POSITIVE
# --------------------------------------------------------------------
# Agent Provocateur Lace by Agent Provocateur (Score: 0.688)
# Top Notes: floral notes, kumquat, saffron, bergamot. Middle Notes: wild orchid, orange blossom, bitter orange, periwinkle. Base Notes: amberwood, musk, cedar.
# Main Accords: citrus, floral, woody, white floral, powdery.
#
# Sentiment: POSITIVE
# --------------------------------------------------------------------
# Truly Lace by Coty (Score: 0.687)
# Top Notes: fruity notes, orange blossom, gardenia, green notes, bergamot. Middle Notes: jasmine, tuberose, lily-of-the-valley, ylang-ylang, rose, orchid. Base Notes: vanilla, amber, sandalwood, musk, oakmoss, cedar.
# Main Accords: white floral, woody, sweet, powdery, fruity.
#
# Sentiment: POSITIVE
# --------------------------------------------------------------------

# %% [markdown]
# # Test (Standard Queries)

# %% [markdown]
# ## Collect Perfume Data

# %%
# Collect notes, accords, occasions arrays to create random user queries
import re
from collections import Counter

note_columns = ["Top", "Middle", "Base"]
accord_columns = [f"mainaccord{i}" for i in range(1, 6)]

def extract_notes_with_threshold(df, columns, min_count=5):
    """
    Extract notes that show up at least min_count times.
    This is to reduce rare nodes, random noise.
    """
    all_notes = []
    for col in columns:
        df[col] = df[col].fillna("")
        split_notes = df[col].str.lower().str.split(",")
        for note_list in split_notes:
            for note in note_list:
                cleaned = re.sub(r"[^a-z\s]", "", note.strip())
                if cleaned and len(cleaned) > 2:
                    all_notes.append(cleaned)

    note_counts = Counter(all_notes)
    filtered = [note for note, count in note_counts.items() if count >= min_count]
    return sorted(filtered)

def extract_accords_with_threshold(df, columns, min_count=3):
    all_accords = []
    for col in columns:
        df[col] = df[col].fillna("")
        for entry in df[col]:
            cleaned = re.sub(r"[^a-z\s]", "", entry.lower().strip())
            if cleaned and len(cleaned) > 2:
                all_accords.append(cleaned)

    accord_counts = Counter(all_accords)
    filtered = [accord for accord, count in accord_counts.items() if count >= min_count]
    return sorted(filtered)

notes = extract_notes_with_threshold(combined_df_classify_reviews, note_columns)
accords = extract_accords_with_threshold(combined_df_classify_reviews, accord_columns)

occasions = [
    "for spring", "for summer", "for fall", "for winter",
    "for date night", "for going out", "for everyday wear", "for special occasions",
    "for the office", "for gym", "for cozy nights", "for beach days",
    "for weddings", "for graduation"
]

# %%
print(notes)
len(notes)
# Out:
# ['absinthe', 'acai berry', 'accia', 'accord eudora', 'african geranium', 'african ginger', 'african orange flower', 'african violet', 'agarwood', 'agarwood oud', 'agave', 'akigalawood', 'aldehydes', 'algae', 'allspice', 'almond', 'almond blossom', 'almond milk', 'almond tree', 'aloe vera', 'amalfi lemon', 'amaretto', 'amaryllis', 'amber', 'amber xtreme', 'ambergris', 'ambertonic', 'amberwood', 'ambrarome', 'ambretone', 'ambrette', 'ambrette musk mallow', 'ambrettolide', 'ambrocenide', 'ambrofix', 'ambroxan', 'amyl salicylate', 'amyris', 'angelica', 'animal notes', 'anise', 'apple', 'apple blossom', 'apple tree', 'apple tree blossom', 'apricot', 'apricot blossom', 'aromatic notes', 'aromatic spices', 'artemisia', 'arum lily', 'asafoetida', 'ash', 'asphalt', 'atlas cedar', 'australian sandalwood', 'baie rose', 'balsam fir', 'balsamic notes', 'bamboo', 'bamboo leaf', 'banana', 'banana leaf', 'barberry', 'barley', 'basil', 'bay leaf', 'beeswax', 'bellflower', 'bellini', 'benzoin', 'bergamot', 'bergamot blossom', 'bergamot leaf', 'berry fruits', 'big strawberry', 'birch', 'birch leaf', 'birch tar', 'biscuit', 'bitter almond', 'bitter orange', 'bitter orange blossom', 'black', 'black amber', 'black cardamom', 'black cherry', 'black currant', 'black currant blossom', 'black currant leaf', 'black elder', 'black fig', 'black iris', 'black leather', 'black licorice', 'black locust', 'black locust honey', 'black musk', 'black orchid', 'black pepper', 'black rose', 'black tea', 'black vanilla husk', 'black violet', 'blackberry', 'blackcurrant syrup', 'blackwood', 'blood grapefruit', 'blood mandarin', 'blood orange', 'blue hyacinth', 'blue lavender', 'blue lotus', 'blue rose', 'blue sage', 'blueberry', 'boletus edulis', 'boronia', 'bourbon geranium', 'bourbon pepper', 'bourbon vanilla', 'bourbon vetiver', 'bourbon whiskey', 'boxwood', 'boysenberry', 'bran', 'brandy', 'brazil nut', 'brazilian orange', 'brazilian redwood', 'brazilian rosewood', 'breubranco', 'broom', 'brown sugar', 'buchu or agathosma', 'buddleia', 'bulgarian rose', 'butter', 'butterfly orchid', 'cabreuva', 'cacao', 'cacao pod', 'cactus', 'cactus flower', 'cade oil', 'calabrian bergamot', 'calabrian mandarin', 'calamus', 'californian lemon', 'calone', 'calypsone', 'cambodian oud', 'camelia', 'camellia', 'campari', 'camphor', 'candied almond', 'candied fruits', 'candied ginger', 'candied orange', 'candy apple', 'cannabis', 'cappuccino', 'carambola star fruit', 'caramel', 'caraway', 'cardamom', 'cardamon', 'carnation', 'carrot', 'carrot seeds', 'casablanca lily', 'cascalone', 'cashmeran', 'cashmere musk', 'cashmere wood', 'cashmirwood', 'cassia', 'cassia bourbon', 'cassis', 'castoreum', 'caviar', 'cedar', 'cedar essence', 'cedar leaves', 'cedar needles', 'cedarmoss', 'cedarwood', 'celery', 'celery seeds', 'cetalox', 'ceylon cinnamon', 'chamomile', 'champaca', 'champagne', 'cherry', 'cherry blossom', 'cherry extract', 'cherry liqueur', 'chestnut', 'chili pepper', 'chinese cedar', 'chinese jasmine', 'chinese osmanthus', 'chinese peony', 'chinotto', 'chocolate', 'chrysanthemum', 'cinammon', 'cinnamon', 'cinnamon leaf', 'cistus incanus', 'citron', 'citrus blossom', 'citrus leaf', 'citruses', 'civet', 'civetta', 'clary sage', 'clearwood', 'clementine', 'cloudberry', 'clove', 'clover', 'cloves', 'co extracts', 'cocacola', 'coconut', 'coconut blossom', 'coconut milk', 'coconut nectar', 'coconut water', 'coffee', 'coffee blossom', 'cognac', 'copahu balm', 'copaiba balm', 'copal', 'coriander', 'coriander leaf', 'costus', 'coton candy', 'cotton candy', 'cotton flower', 'coumarin', 'cranberry', 'creme brulee', 'crystal amber', 'cucumber', 'cumin', 'cupcake', 'currant buds', 'curry tree', 'custard', 'cyclamen', 'cypress', 'cypress leaf', 'cypriol oil or nagarmotha', 'dahlia', 'daisy', 'damask plum', 'damask rose', 'dark chocolate', 'dark woodsy notes', 'dates', 'datura', 'davana', 'desert rose', 'dew drop', 'dewberry', 'dreamwood', 'dried fruits', 'dried plum', 'driftwood', 'dry wood', 'd ...
# 911

# %%
print(accords)
len(accords)
# Out:
# ['alcohol', 'aldehydic', 'almond', 'amber', 'animalic', 'anis', 'aquatic', 'aromatic', 'asphault', 'balsamic', 'beeswax', 'bitter', 'cacao', 'camphor', 'cannabis', 'caramel', 'champagne', 'cherry', 'chocolate', 'cinnamon', 'citrus', 'clay', 'cocacola', 'coconut', 'coffee', 'conifer', 'earthy', 'floral', 'fresh', 'fresh spicy', 'fruity', 'green', 'herbal', 'honey', 'iris', 'lactonic', 'lavender', 'leather', 'marine', 'metallic', 'mineral', 'mossy', 'musky', 'nutty', 'oriental', 'oud', 'ozonic', 'patchouli', 'powdery', 'rose', 'rum', 'salty', 'sand', 'savory', 'smoky', 'soapy', 'soft spicy', 'sour', 'spicy', 'sweet', 'tobacco', 'tropical', 'tuberose', 'vanilla', 'vinyl', 'violet', 'vodka', 'warm spicy', 'whiskey', 'white floral', 'wine', 'woody', 'yellow floral']
# 73

# %% [markdown]
# ## Create Random User Queries

# %%
import random

def generate_random_query(notes, accords, occasions):
    note1, note2 = random.sample(notes, 2)
    accord = random.choice(accords)
    occasion = random.choice(occasions)
    return f"I want something {accord} with {note1} and {note2} {occasion}."

# %%
num_queries = 50
query_path = "/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/testing/standard_user_queries.csv"

# Check if file exists
if os.path.exists(query_path):
    print(f"Loading existing user_queries...")
    query_df = pd.read_csv(query_path)

else:
    print("No user_queries, needs to generating new queries...")

    # Generate new queries
    generated_queries = [generate_random_query(notes, accords, occasions) for _ in range(num_queries)]
    generated_queries = list(set(generated_queries))  # remove duplicates

    query_df = pd.DataFrame({"query": generated_queries})
    query_df.to_csv(query_path, index=False)

    print(f"Saved {num_queries} user queries to {query_path}")

query_df.head()
# Out:
# Loading existing user_queries...
#                                                query
# 0  I want something sand with cherry and hiacynth...
# 1  I want something tobacco with coriander and pl...
# 2  I want something anis with tobacco blossom and...
# 3  I want something cannabis with magnolia petals...
# 4  I want something iris with juniper and hazelnu...

# %% [markdown]
# ## Build Feedback File

# %%
feedback_path = "/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/testing/without-tags/standard_user_feedback_without_tags.csv"

if not os.path.exists(feedback_path):
    with open(feedback_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["query", "perfume_name", "brand", "score", "label", "notes_and_accords"])
    print("Created new feedback file.")
else:
    print("Feedback file already exists — ready to append new rows.")


def recommend_perfumes(user_query, top_k=5, max_feedback=3):
    """
    Recommend perfumes based on the raw query (no tags).
    Ask for Yes/No feedback on up to max_feedback perfumes.
    """

    query_embedding = s_model.encode(user_query, convert_to_tensor=True)
    scent_tensor = perfume_embeddings.to(query_embedding.device)

    similarities = util.cos_sim(query_embedding, scent_tensor)[0]

    adjusted_scores = []
    for idx, score in enumerate(similarities):
        sentiment_boost = 1.2 if combined_df_classify_reviews.loc[idx, 'is_positive'] == 1 else 0.8
        adjusted_scores.append(score.item() * sentiment_boost)

    adjusted_scores = torch.tensor(adjusted_scores)
    top_results = torch.topk(adjusted_scores, k=top_k)

    # print(f"\nUser Query: {user_query}\n")

    # Only display a number of user queries until reaching max_feedback
    feedback_count = 0
    new_feedback = []
    for score, idx in zip(top_results.values, top_results.indices):
        if feedback_count >= max_feedback:
            break

        idx = idx.item()
        perfume = combined_df_classify_reviews.loc[idx]
        perfume_name = perfume['Perfume']
        brand = perfume['Brand']

        print(f"\n{perfume_name} by {brand} (Score: {score.item():.3f})")
        short_desc = (
            f"Top Notes: {perfume['Top']}. "
            f"Middle Notes: {perfume['Middle']}. "
            f"Base Notes: {perfume['Base']}.\n"
            f"Main Accords: {', '.join([str(perfume.get(f'mainaccord{i}', '')) for i in range(1, 6)])}."
        )
        print(f"{short_desc}\n")
        print(f"Sentiment: {perfume['sentiment']}")
        print("-" * 70)

        while True:
            label = input(f"Do you like '{perfume_name}' by {brand}? (Yes/No or type 'skip'): ").strip().capitalize()
            if label in ["Yes", "No"]:
                break
            elif label == "Skip":
                print(f"Skipping '{perfume_name}' for query: {user_query}")
                label = None
                break
            else:
                print("Please type 'Yes', 'No', or 'skip'. Try again.")

        notes_and_accords = (
            f"Top: {perfume['Top']} | "
            f"Middle: {perfume['Middle']} | "
            f"Base: {perfume['Base']} | "
            f"Accords: {', '.join([str(perfume.get(f'mainaccord{i}', '')) for i in range(1, 6)])}"
        )

        if label is not None:
            new_feedback.append([
                user_query,
                perfume_name,
                brand,
                score.item(),
                label,
                notes_and_accords
            ])
            feedback_count += 1

    # Append new feedback to CSV
    if new_feedback:
        with open(feedback_path, "a", newline="") as f:
            writer = csv.writer(f)
            writer.writerows(new_feedback)
        print(f"\nLogged {len(new_feedback)} new feedback entries.")
    else:
        print("\nNo new feedback was logged.")
# Out:
# Feedback file already exists — ready to append new rows.

# %%
# Loop through queries starting from a requested index
while True:
    start_index_input = input("Enter the query index: ").strip()
    if start_index_input == "" or start_index_input.isdigit():
        break
    else:
        print("Please enter valid number.")

start_index = int(start_index_input) - 1 if start_index_input else 0

for i, row in query_df.iloc[start_index:].iterrows():
    user_query = row['query']
    print(f"\n==============================")
    print(f"Query {i+1}/{len(query_df)}: {user_query}")
    print(f"==============================")

    recommend_perfumes(user_query, top_k=3, max_feedback=3)

    cont = input("Press Enter to continue, type 'skip' to skip this query, or 'stop' to quit: ").strip().lower()

    if cont == 'stop':
        print("Stopping early.")
        break
    elif cont == 'skip':
        print(f"Skipping query {i+1}: {user_query}")
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1732404331.py in <cell line: 0>()
#       1 # Loop through queries starting from a requested index
#       2 while True:
# ----> 3     start_index_input = input("Enter the query index: ").strip()
#       4     if start_index_input == "" or start_index_input.isdigit():
#       5         break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Compute Relevance Scores

# %%
feedback_df = pd.read_csv(feedback_path)

feedback_df["label"] = feedback_df["label"].str.lower().str.strip()

# Group feedback by query
grouped = feedback_df.groupby("query")

recall_scores = []
for query, group in grouped:
    total = len(group)
    relevant = sum(group["label"] == "yes")
    recall = relevant / total if total > 0 else 0
    recall_scores.append(recall)

# Average all ratio of yes
avg_recall = sum(recall_scores) / len(recall_scores)
print(f"Average fraction of relevant items in top-k: {avg_recall:.2f} over {len(recall_scores)} queries and {len(feedback_df)} feedback")
# Out:
# Average fraction of relevant items in top-k: 0.89 over 34 queries and 102 feedback

# %% [markdown]
# # Test (Non-standard Queries)

# %% [markdown]
# ## Create Non-standard User Queries

# %%
import json
import pandas as pd

num_queries = 50
query_path_non_standard = "/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/testing/non_standard_user_queries.csv"


# Check if file exists
if os.path.exists(query_path_non_standard):
    print(f"Loading existing user_queries...")
    query_df_non_standard = pd.read_csv(query_path_non_standard)

else:
    print("No user_queries, needs to generating new queries...")

    jsonl_path = "/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/testing/training_data.jsonl"

    instructions = []

    with open(jsonl_path, "r", encoding="utf-8") as f:
        for line in f:
            data = json.loads(line)
            if "instruction" in data:
                instructions.append(data["instruction"])
            if len(instructions) == 50:
                break

    query_df_non_standard = pd.DataFrame({"query": instructions})
    query_df_non_standard.to_csv(query_path_non_standard, index=False) # save to CSV

query_df_non_standard.head()
# Out:
# Loading existing user_queries...
#                                                query
# 0  What perfumes capture the essence of a natural...
# 1                     scent of a confident adventure
# 2                      perfume for a womanly mansion
# 3  I'm going to a homey alchemy lab. What scents ...
# 4  I'm going to a hiking sea. What scents would y...

# %% [markdown]
# ## Build Feedback File

# %%
feedback_path_non_standard = "/content/drive/MyDrive/Colab Notebooks/totallymakescents/data/testing/without-tags/non_standard_user_feedback_without_tags.csv"

if not os.path.exists(feedback_path_non_standard):
    with open(feedback_path_non_standard, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["query", "perfume_name", "brand", "score", "label", "notes_and_accords"])
    print("Created new feedback file.")
else:
    print("Feedback file already exists — ready to append new rows.")


def recommend_perfumes(user_query, top_k=5, max_feedback=3):
    """
    Recommend perfumes based on the raw query (no tags).
    Ask for Yes/No feedback on up to max_feedback perfumes.
    """

    query_embedding = s_model.encode(user_query, convert_to_tensor=True)
    scent_tensor = perfume_embeddings.to(query_embedding.device)

    similarities = util.cos_sim(query_embedding, scent_tensor)[0]

    adjusted_scores = []
    for idx, score in enumerate(similarities):
        sentiment_boost = 1.2 if combined_df_classify_reviews.loc[idx, 'is_positive'] == 1 else 0.8
        adjusted_scores.append(score.item() * sentiment_boost)

    adjusted_scores = torch.tensor(adjusted_scores)
    top_results = torch.topk(adjusted_scores, k=top_k)

    # print(f"\nUser Query: {user_query}\n")

    # Only display a number of user queries until reaching max_feedback
    feedback_count = 0
    new_feedback = []
    for score, idx in zip(top_results.values, top_results.indices):
        if feedback_count >= max_feedback:
            break

        idx = idx.item()
        perfume = combined_df_classify_reviews.loc[idx]
        perfume_name = perfume['Perfume']
        brand = perfume['Brand']

        print(f"\n{perfume_name} by {brand} (Score: {score.item():.3f})")
        short_desc = (
            f"Top Notes: {perfume['Top']}. "
            f"Middle Notes: {perfume['Middle']}. "
            f"Base Notes: {perfume['Base']}.\n"
            f"Main Accords: {', '.join([str(perfume.get(f'mainaccord{i}', '')) for i in range(1, 6)])}."
        )
        print(f"{short_desc}\n")
        print(f"Sentiment: {perfume['sentiment']}")
        print("-" * 70)

        while True:
            label = input(f"Do you like '{perfume_name}' by {brand}? (Yes/No or type 'skip'): ").strip().capitalize()
            if label in ["Yes", "No"]:
                break
            elif label == "Skip":
                print(f"Skipping '{perfume_name}' for query: {user_query}")
                label = None
                break
            else:
                print("Please type 'Yes', 'No', or 'skip'. Try again.")

        notes_and_accords = (
            f"Top: {perfume['Top']} | "
            f"Middle: {perfume['Middle']} | "
            f"Base: {perfume['Base']} | "
            f"Accords: {', '.join([str(perfume.get(f'mainaccord{i}', '')) for i in range(1, 6)])}"
        )

        if label is not None:
            new_feedback.append([
                user_query,
                perfume_name,
                brand,
                score.item(),
                label,
                notes_and_accords
            ])
            feedback_count += 1

    # Append new feedback to CSV
    if new_feedback:
        with open(feedback_path, "a", newline="") as f:
            writer = csv.writer(f)
            writer.writerows(new_feedback)
        print(f"\nLogged {len(new_feedback)} new feedback entries.")
    else:
        print("\nNo new feedback was logged.")
# Out:
# Created new feedback file.

# %% [markdown]
# ## Compute Relevance Scores

# %%
feedback_df = pd.read_csv(feedback_path_non_standard)

feedback_df["label"] = feedback_df["label"].str.lower().str.strip()

# Group feedback by query
grouped = feedback_df.groupby("query")

recall_scores = []
for query, group in grouped:
    total = len(group)
    relevant = sum(group["label"] == "yes")
    recall = relevant / total if total > 0 else 0
    recall_scores.append(recall)

# Average all ratio of yes
avg_recall = sum(recall_scores) / len(recall_scores)
print(f"Average fraction of relevant items in top-k: {avg_recall:.2f} over {len(recall_scores)} queries and {len(feedback_df)} feedback")
