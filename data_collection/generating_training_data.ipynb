# %%
import numpy as np
import pandas as pd
import json
import random
import itertools
from pathlib import Path

# %% [markdown]
# # Constructing (notes, note_group)

# %%
notes_df = pd.read_csv('notes.csv',index_col=0)
notes_df = notes_df.drop(labels=['group_description','note_img'], axis=1,inplace=True)

# %%
notes_df.sample(10)
# Out:
#                                     note_group              note
# 1363                                 beverages  mai tai cocktail
# 1414  natural and synthetic, popular and weird  alcantara accord
# 857                                     spices         coriander
# 1662  natural and synthetic, popular and weird    vinyl guaiacol
# 479                                    flowers      ornithogalum
# 142                fruits, vegetables and nuts        green pear
# 1319                                 beverages    blue margarita
# 1475  natural and synthetic, popular and weird       diving suit
# 969                 sweets and gourmand smells          dragibus
# 5                                citrus smells         calamansi

# %%
scent_bank = []

# %%
# these categories are split off and fully redefined 

fruits = [
    "acai berry", "acerola", "akebia fruit", "apple", "apple juice", "apple pulp", "apple sherbet",
    "apricot", "arctic bramble", "ashberry", "banana", "barberry", "bearberry", "black cherry",
    "black currant", "black sapote", "blackberry", "blackthorn", "blueberry", "boysenberry",
    "buriti", "burning cherry", "cabernet grape", "cantaloupe", "carambola (star fruit)",
    "cassowary fruit", "cherimoya","cherry", "cherry jam", "chinese magnolia","cloudberry", "coco de mer", "coconut",
    "coconut water", "count's fruit", "cranberry", "cupuaçu, cupuassu, copoasu",
    "dark plum wu mei", "dewberry", "dried apple crisp", "dried apricot", "dried fruits",
    "durian", "elderberry", "feijoa fruit", "fig", "forest fruits", "frosted berries",
    "fruit salad", "fruity notes", "fuji apple", "gariguette strawberry", "genipapo",
    "goji berries", "gooseberry", "grape seed", "grapes", "green anjou pears", "green grape",
    "green pear", "green plum", "greengage", "ground cherry", "guarana", "guava", "hog plum",
    "honeydew melon", "isabella grape", "jabuticaba", "jackfruit", "japanese loquat", "kiwi",
    "lingonberry", "litchi", "loganberry", "longan berries", "lucuma", "mamey", "mango",
    "mangosteen", "maninka", "marian plum", "medlar", "melon", "mirabelle", "miracle berry",
    "mulberry", "nashi pear", "nectarine", "papaya", "passionfruit", "peach", "pear",
    "persimmon", "pineapple", "pinot noir grapes", "pitahaya", "pitanga", "plantain", "plum",
    "pomegranate", "prickly pear", "quandong desert peach", "quince", "rambutan", "raspberry",
    "red apple", "red berries", "red currant", "red fruits", "red fruits smoothie", "red mulberry",
    "salak", "santol", "sapodilla", "sea buckthorn", "seriguela", "silverberry", "snowberry",
    "sour cherry", "soursop", "star apple", "strawberry", "tayberry", "tropical fruits",
    "tropicalone", "tucumã", "water fruit", "watermelon", "white currant", "white grape",
    "white mulberry", "wild strawberry", "williams pear", "winterberry", "wolfberry",
    "yellow cherry", "yellow fruits", "yumberry","blackcurrant juice", "cherry liqueur", "cocktail fruits", "fruit tea",
    "lemon soda", "lemonade", "orange soda", "pear juice",'little doll strawberry',
     'antillone™','apple shisha accord','hexyl acetate','pearadise®', 'melonal',
     'dihydromyrcenol','pomarose','veloutone','verdox','fruity','tropical','cherry'
]

vegetables_and_nuts = [
    "acorn", "almond", "argan", "artichoke", "beetroot", "bitter melon", "black walnut",
    "brazil nut", "breadnut", "candlenut", "carrot", "cashew", "cauliflower", "cepes",
    "chayote", "chestnut", "chia seed", "chickpeas", "cocoa shell", "cogumelo porcino","conifer", "corn",
    "corn silk", "cucumber", "currant leaf and bud", "cyperus scariosus", "daikon radish",
    "fig leaf", "fig milk", "grains", "hazelnut", "jobs tears (yi yi ren)", "kumbaru",
    "macadamia", "mahonia", "malt", "moepel accord", "mung bean", "mushroom", "nutty notes",
    "okra seeds", "olive", "pea", "peanut", "pecan", "peruvian pepper", "pistachio",
    "potato", "pumpkin", "purple yam", "rhubarb", "roasted nuts", "sarsaparilla",
    "serrano pepper", "shea butter", "shea nuts", "soybean", "squash", "tamanu", "taro",
    "tomato", "vegetal notes", "walnut", "walnut milk", "wattleseed", "yuca cassava",
    "carrot seeds",'tomato sauce','nutty'
]

alcoholic = [
    "absinthe", "advocaat", "amaretto", "amarula", "aperol", "applejack",
    "baileys irish cream", "batida", "beer", "beer/ale", "bellini",
    "blue margarita", "boozy notes", "bourbon whiskey", "buttered rum",
    "cachaça", "caipirinha", "calvados drink", "campari", 'champagne',"champagne rosé","cherry liqueur",
    "cognac", "cosmopolitan cocktail", "cream liqueur", "curaçao", "daiquiri",
    "eau de vie", "génépi", "gin", "goldwasser", "ice wine", "kir royal",
    "limoncello", "liquor", "madeira", "mai tai cocktail", "margarita",
    "martini", "mezcal", "midori", "mojito", "moonshine", "moscow mule",
    "mulled wine", "negroni", "ouzo", "pina colada", "pisco sour cocktail",
    "pistachio liquer", "plum liquor", "plum wine", "port wine", "prosecco",
    "punch", "raki", "red wine", "rhum agricole", "rum", "sake", "sangria",
    "sauce-aroma baijiu", "soju", "sparkling wine", "tequila", "tokaji wine",
    "umeshu", "vermouth", "vodka", "whiskey", "white wine", "wine lees",
    "wine must"
]

musk_and_amber = [
    "akashic acord", "aldron", "amber", "amber xtreme", "ambergris",
    "ambertonic™ (iff)", "ambergris","ambrarome", "ambretone", "ambrette (musk mallow)",
    "ambrettolide", "ambrocenide (symrise)", "ambrostar", "ambroxan",
    "anthamber™", "cetalox", "exaltolide®", "habanolide®", "kephalis",
    "kyphi", "muscone", "musk", "sylkolide", "velvione™",'ambrox® super',
    'tonalide®','tonquitone™','ambreine','ambrinol','galaxolide','lorenox',
    'muscenone','cashalox','cashmeran','cosmone','helvetolide','hina',
    'serenolide', 'operanide','sclarene','sinfonide','musky'
]

animalic = [
    "animal notes", "bacon", "bbq", "beeswax", "castoreum",
    "caviar", "cheese", "civet", "civettone", "daim", "fur",
    "genet", "goat hair", "goat's milk", "hyraceum", "leather", "meat",
    "milk", "muskrat", "saffiano leather",
    "skatole", "skin", "suede", "truffle", 'black leather', 'white leather', 'wool',
    "ambergris","ambrarome","ambrostar", "cetalox","muscone",'ambrox® super',
    'lactones','suederal®','ambrinol','indole','isobutyl quinoline',
    'soy sauce','leather','musky','savory','animalic'
]

# these are new categories

urban = [
    'asphalt', 'cigarette', 'concrete', 'credit cards', 'glass', 
    'ink', 'jeans', 'money', 'neoprene', 'new magazine', 'petroleum',
    'pink crystal', 'plastic', 'plastic bag',
    'spray paint', 'vinyl', 'vinyl guaiacol','wet plaster','gunpowder',
    'motor oil','lip gloss', 'lipstick','brick', 'brown scotch tape',
    'gasoline','co2 extracts','instant film accord','varnish accord',
    'latex','caoutchouc','tar','aluminum', 'graphite', 'copper', 'gold', 
    'hot iron', 'metallic notes', 'silver',
    'pharaone®','scent trek®','factor x', 'iodine','hand cream',
    'industrial glue','nail polish', 'hair pomade','ammonia','melbaton',
    'sodium silicate','rubber','industrial glue','asphault','metallic'
]

weird = [
    'blood', 'cocaine', 'egg' , 'mascarpone cheese', 'pizza',
    'play-doh', 'poison', 'soap', 'sweat', 'mayonnaise accord',
    'toothpaste',"goat's milk",'tennis ball'
]


ocean = ['solar notes','sea foam', 'sea water', 'crustaceans', 'pink himalayan sea salt', 
        "coral reef","oysters","sea shells","starfish",'thalassogaia™',
        'siren', 'diving suit','sand','re base','sunscreen', 'suntan lotion','ozonic',
        'fresh spicy','fresh','tropical','marine','aquatic'
]

water = [
    'aquozone', 'floralozone', 'head space waterfall', 'holy water', 'ice',
    'water','wet stone','fish','mitti attar','dew drop','sauna','aqual™',
    'rain notes', 'river notes','steam accord','thalassogaia™','geosmin',
    'calone','calypsone','cascalone','snow','ozonic','fresh spicy','fresh',
    'marine','aquatic'
]

earthy = [
    'cobblestone', 'coral limestone', 'dirt', 'earth tincture', 'mud',
    'salt', 'sand', 'stone','yeast','straw','naturalcalm™',
    'pebbles','clay','earthy notes','mineral notes',
    'slate','loam','camphor','chalk','coumarin','terracotta','earthy',
    'mineral'
]


clean = [
    'fabric','linen','accord eudora®','alcantara accord','ambrofix™',
    'hivernal®','osmasylk natsublim™','steam accord','t-shirt accord',
    'toothpaste','aldehydes','tulle accord','powdery notes','calone',
    'calypsone','ozonic notes','mountain air', 'lavender','soapy'
]

old = [
    'priest’s clothes','old books', 'old house','pencil','paper', 'parchment', 
    'candle wax', 'canvas', 'cork',"kyphi",'holy water','dust'
]

smoke = [
    'ash', 'burnt match','fire', 'smoke','lava','cuban cigar','flint',
    'coal','coal tar pitch','sulphur', 'hashish','apple shisha accord',
    'trimofix®','guaiacol','ember','mystikal','peat','sp3 carbon','smoky',
    'coffee'
]


oppulence = [
    'black diamond', 'satin','silk', 'porcelain','pearls',
    "caviar",'mousse de saxe','dodecanal','mystikal','orbitone',
    'velvet',"ambergris","ambertonic™ (iff)", "ambergris","ambrarome", 
    "ambretone", "ambrette (musk mallow)","ambrettolide", "ambrocenide (symrise)", 
    "ambrostar", "ambroxan",'olibanum (frankincense)','myrrh',
    'agarwood (oud)','sandalwood','patchouli', 'patchouli (green)',
    'leather', 'saffiano leather', 'black leather', 'white leather',
    'truffle','gold','silver','leather','tobacco','coffee'
]

# %%
for fruit in fruits:
    scent_bank.append( (fruit,'fruits') )
for veg in vegetables_and_nuts:
    scent_bank.append( (veg,'vegetables and nuts') )
for alc in alcoholic:
    scent_bank.append( (alc,'alcoholic') )
for musk in musk_and_amber:
    scent_bank.append( (musk,'musk and amber') )
for animal in animalic:
    scent_bank.append( (animal,'animalic') )
for urban_note in urban:
    scent_bank.append( (urban_note,'urban') )
for weird_note in weird:
    scent_bank.append( (weird_note,'weird') )
for ocean_note in ocean:
    scent_bank.append( (ocean_note,'ocean') )
for water_note in water:
    scent_bank.append( (water_note,'water') )
for earthy_note in earthy:
    scent_bank.append( (earthy_note,'earthy') )
for clean_note in clean:
    scent_bank.append( (clean_note,'clean') )
for old_note in old:
    scent_bank.append( (old_note,'old') )
for smoke_note in smoke:
    scent_bank.append( (smoke_note,'smoke') )
for op_note in oppulence:
    scent_bank.append( (op_note,'oppulence') )

# %%
# these just need to be appended to existing categories

flowers = ['para-cresyl phenyl acetate','rose oxide','salicylic acid',
        'floratta dna','ionones','magnolan','mugane','bourgeonal',
        'tuberolide','coranol','damascone','prunol','rhodinol','rose',
        'white floral','iris']

white_flowers = ['jasmolactone','lilybelle®','nympheal™','jasmone',
                'cyclopidene','hedione','paradisone']

green_herbs = ['eugenol','rice powder','clarycet','pollen', 'propolis','sisal rope', 
               'western honey bee','mountain air','hexenyl green','spiranol','green',
                'lavender','herbal','mossy']

woods_and_mosses = ['terpineol','georgywood','healingwood', 'lacquered wood', "kephalis",
    'pepperwood™', 'cetonal®','iso e super','norlimbanol™','orcanox™','timbersilk™',
    'trimofix®','aldambre','amyl salicylate','evernyl','isobutyl quinoline',
    'javanol','boisiris','hindinol','operanide','terranol','timberol','z-11 hd','woody']

sweet = ['fior di latte', 'molasses', 'red bean paste', 'vanillin', 'azarbre','ethyl maltol','ember', 'flour',
        'sweet','vanilla','cacao','chocolate','honey','caramel']

citrus = ['dodecanal','vitamin c','citrus']

spices = ['pepperwood™','osmasylk natsublim™','cinnamaldehyde','poivrol','warm spicy',
          'oriental','anis']

resins = ["tolu balsam",'talc']

flowers = pd.DataFrame({'note_group':['flowers']*len(flowers), 'note':flowers})
white_flowers = pd.DataFrame({'note_group':['white flowers']*len(white_flowers), 'note':white_flowers})
green_herbs = pd.DataFrame({'note_group':['greens, herbs and fougeres']*len(green_herbs), 'note':green_herbs})
woods_and_mosses = pd.DataFrame({'note_group':['woods and mosses']*len(woods_and_mosses), 'note':woods_and_mosses})
sweet = pd.DataFrame({'note_group':['sweets and gourmand smells']*len(sweet), 'note': sweet})
citrus = pd.DataFrame({'note_group':['citrus smells']*len(citrus), 'note': citrus})
spices = pd.DataFrame({'note_group':['spices']*len(spices), 'note': spices})
resins = pd.DataFrame({'note_group':['resins and balsams']*len(resins), 'note': resins})

notes_df = pd.concat([notes_df, flowers, white_flowers, green_herbs, woods_and_mosses, sweet, citrus, spices, resins], ignore_index=True)

# %%
to_drop = (notes_df['note_group']=='natural and synthetic, popular and weird') | (notes_df['note_group']=='uncategorized')  | (notes_df['note_group']=='beverages') | (notes_df['note_group']=='fruits, vegetables and nuts') | (notes_df['note_group']=='musk, amber, animalic smells')
notes_df = notes_df[~to_drop]

# %%
for note,group in zip(notes_df['note'], notes_df['note_group']):
    scent_bank.append((note, group))

# %% [markdown]
# # Themes and their associated perfume notes

# %%
theme_scent_dict = {
    'culinary': list(itertools.chain(
        [note for note in scent_bank if 'spices' in note],
        random.sample([note for note in scent_bank if 'sweets and gourmand smells' in note],70),
        [note for note in scent_bank if 'vegetables and nuts' in note],
        random.sample([note for note in scent_bank if 'fruits' in note],40)
        )),
    'fruits':list(itertools.chain(
        [note for note in scent_bank if 'fruits' in note],
        [note for note in scent_bank if 'citrus smells' in note]
        )),
    'aquatic':list(itertools.chain(
        [note for note in scent_bank if 'water' in note],
        [note for note in scent_bank if 'ocean' in note]
        )),
    'rich':list(itertools.chain(
        [note for note in scent_bank if 'oppulence' in note],
        random.sample([note for note in scent_bank if 'musk and amber' in note],15),
        random.sample([note for note in scent_bank if 'alcoholic' in note],15)
        )),
    'rugged':list(itertools.chain(
        [note for note in scent_bank if 'musk and amber' in note],
        [note for note in scent_bank if 'animalic' in note],
        [note for note in scent_bank if 'smoke' in note]
        )),   
    'soft':list(itertools.chain(
        [note for note in scent_bank if 'flowers' in note],
        [note for note in scent_bank if 'white flowers' in note],
        [note for note in scent_bank if 'sweets and gourmand smells' in note]
        )),
    'old':list(itertools.chain(
        [note for note in scent_bank if 'old' in note],
        random.sample([note for note in scent_bank if 'smoke' in note],5),
        random.sample([note for note in scent_bank if 'earthy' in note],5),
        random.sample([note for note in scent_bank if 'resins and balsams' in note],5),
        )),
    'exotic':list(itertools.chain(
        [note for note in scent_bank if 'spices' in note],
        random.sample([note for note in scent_bank if 'greens, herbs and fougeres' in note],20),
        [note for note in scent_bank if 'earthy' in note]
        )),
    'urban':list(itertools.chain(
        [note for note in scent_bank if 'urban' in note],
        [note for note in scent_bank if 'weird' in note],
        random.sample([note for note in scent_bank if 'alcoholic' in note],25),
        [note for note in scent_bank if 'clean' in note],
        )),
    'home':list(itertools.chain(
        [note for note in scent_bank if 'clean' in note],
        random.sample([note for note in scent_bank if 'sweets and gourmand smells' in note],5),
        random.sample([note for note in scent_bank if 'citrus smells' in note],5)
        )),  
    'fantasy':list(itertools.chain(
        [note for note in scent_bank if 'old' in note],
        random.sample([note for note in scent_bank if 'resins and balsams' in note],5),
        random.sample([note for note in scent_bank if 'woods and mosses' in note],5),
        random.sample([note for note in scent_bank if 'earthy' in note],5),
        random.sample([note for note in scent_bank if 'smoke' in note],5),
        random.sample([note for note in scent_bank if 'flowers' in note],5),
        random.sample([note for note in scent_bank if 'spices' in note],5),
        )),  
    'dystopian':list(itertools.chain(
        [note for note in scent_bank if 'urban' in note],
        [note for note in scent_bank if 'weird' in note],
        random.sample([note for note in scent_bank if 'alcoholic' in note],10),
        random.sample([note for note in scent_bank if 'clean' in note],5),
        random.sample([note for note in scent_bank if 'smoke' in note],5)
        )),  
    'action':list(itertools.chain(
        [note for note in scent_bank if 'urban' in note],
        [note for note in scent_bank if 'musk and amber' in note],
        [note for note in scent_bank if 'smoke' in note]
        )),  
    'romance':list(itertools.chain(
        random.sample([note for note in scent_bank if 'flowers' in note],100),
        random.sample([note for note in scent_bank if 'sweets and gourmand smells' in note],100),
        [note for note in scent_bank if 'white flowers' in note],
        random.sample([note for note in scent_bank if 'fruits' in note],100)
        )),  
    'nature':list(itertools.chain(
        [note for note in scent_bank if 'woods and mosses' in note],
        random.sample([note for note in scent_bank if 'greens, herbs and fougeres' in note],80),
        random.sample([note for note in scent_bank if 'flowers' in note],80),
        [note for note in scent_bank if 'earthy' in note],
        [note for note in scent_bank if 'animalic' in note],
        random.sample([note for note in scent_bank if 'vegetables and nuts' in note],25),
        )),  
    'clean':list(itertools.chain(
        [note for note in scent_bank if 'clean' in note],
        random.sample([note for note in scent_bank if 'citrus smells' in note],10),
        random.sample([note for note in scent_bank if 'water' in note],10),
        random.sample([note for note in scent_bank if 'musk and amber' in note],10),
        random.sample([note for note in scent_bank if 'woods and mosses' in note],10)
        )),  
    'sci-fi':list(itertools.chain(
        [note for note in scent_bank if 'weird' in note],
        [note for note in scent_bank if 'urban' in note],
        random.sample([note for note in scent_bank if 'spices' in note],20),
        random.sample([note for note in scent_bank if 'animalic' in note],10),
        random.sample([note for note in scent_bank if 'oppulence' in note],10),
        [('ozonic notes','clean'),('mountain air','clean'),('copper', 'urban'),('gold', 'urban'),('hot iron', 'urban'),
        ('metallic notes','urban'),('silver','urban')]
        )),  
    'intense':list(itertools.chain(
        random.sample([note for note in scent_bank if 'musk and amber' in note],20),
        random.sample([note for note in scent_bank if 'urban' in note],20),
        random.sample([note for note in scent_bank if 'alcoholic' in note],20),
        random.sample([note for note in scent_bank if 'animalic' in note],10),
        random.sample([note for note in scent_bank if 'smoke' in note],10),
        random.sample([note for note in scent_bank if 'oppulence' in note],15),
        )),  
    'calm':list(itertools.chain(
        random.sample([note for note in scent_bank if 'water' in note],20),
        random.sample([note for note in scent_bank if 'flowers' in note],20),
        [note for note in scent_bank if 'ocean' in note],
        random.sample([note for note in scent_bank if 'woods and mosses' in note],20),
        random.sample([note for note in scent_bank if 'vegetables and nuts' in note],20),
        [note for note in scent_bank if 'clean' in note],
        )),  
    'happy':list(itertools.chain(
        random.sample([note for note in scent_bank if 'citrus smells' in note],30),
        random.sample([note for note in scent_bank if 'flowers' in note],30),
        random.sample([note for note in scent_bank if 'white flowers' in note],30),
        random.sample([note for note in scent_bank if 'sweets and gourmand smells' in note],30),
        random.sample([note for note in scent_bank if 'fruits' in note],30),
        random.sample([note for note in scent_bank if 'alcoholic' in note],20),
        [note for note in scent_bank if 'clean' in note],
        )),
    'tropical':list(itertools.chain(
        random.sample([note for note in scent_bank if 'citrus smells' in note],40),
        random.sample([note for note in scent_bank if 'fruits' in note],30),
        random.sample([note for note in scent_bank if 'flowers' in note],30),
        [note for note in scent_bank if 'ocean' in note],
        [note for note in scent_bank if 'water' in note],
        random.sample([note for note in scent_bank if 'alcoholic' in note],30)
        )),
}

# %% [markdown]
# # Prompt Base,Descriptor, and Setting

# %%
base_prompts = [
    "What does it smell like in {}?",
    "Give me scents associated with {}.",
    "What are the dominant smells in {}?",
    "Which fragrances evoke the mood of {}?",
    "If you were to bottle the scent of {}, what would it contain?",
    "What scents give the aroma of {}?",
    "What perfumes smell like {}?",
    "What smells would make me feel like I'm in {}?",
    "What are appropriate scents for {}?",
    "What perfumes capture the essence of {}?",
    "Recommend me perfumes that smell like {}.",
    "I'm going to {}. What scents would you recommend?",
    "Which perfumes best represent {}?",
    "what olfactory notes would capture the feeling of {}?",
    "What fragrances embody the smell of {}?",
    'What would a perfume inspired by {} smell like?',
    "the smell of {}",
    "perfume for {}",
    'scent of {}',
    "{}",
]

# %%
theme_dict = {
    'culinary': {'culinary','spicy','sweet','aromatic','oven-baked','delicious','baked','home-cooked','mouthwatering'},
    'fruits':{'fruity','natural','organic','ripe','juicy','summery','sunny','healthy'},
    'aquatic':{'aquatic','nautical','ocean-side','sea','marine','river-side','lake-side','rainy','coastal','crisp','winter'},
    'rich':{'rich','luxury','opulent','expensive','wealthy','exclusive','golden','silver','decadent','luxurious'},
    'rugged':{'manly','masculine','rugged','tough','strong','leathery','whiskey','old-school','raw','powerful','bold'},
    'soft':{'feminine','dainty','delicate','womanly','beautiful','nurturing','floral'},
    'old':{'old','vintage','antique','nostalgic','ancient','aged','medieval','dusty','historical','archaic'},
    'exotic':{'exotic','foreign','mysterious','cultural','tribal','ornate','faraway'},
    'urban':{'urban','downtown','metropolitan','modern','industrial','graffiti','neon','nightlife','contemporary','traffic','polluted'},
    'home':{'homey','cozy','comfortable','warm','familial','domestic','safe','bedroom','sleeping'},
    'fantasy':{'fantasy','fantastical','magical','mystical','arcane','enchanted','castle','dragon','elven','sorcerer','wizard','Hogwarts'},
    'dystopian':{'dystopian','industrial','wasteland','ruined','post-apocalyptic','survivalist','rebel','rebellion','metallic'},
    'action':{'action','adventuring','thrilling','adrenaline','explosive','gunfire','heroic'},
    'romance':{'romantic','love','passionate','affectionate','intimate','seductive','date-night','valentine\'s','candlelit','wedding','wedding anniversary'},
    'nature':{'forest','natural','mountain','prairie','field','woodsy','wild','outdoors','camping','hiking','trees','wooden','jungle','autumn'},
    'clean':{'clean','fresh','freshly laundered','soapy','watery','cool','crisp','airy','healthy'},
    'sci-fi':{'sci-fi','future','space','alien','technological','cyberpunk','robotic','cyborg','spaceship','futuristic','time travel'},
    'intense':{'intense','passionate','strong','confident','bold','fierce','charismatic','assertive','dominant'},
    'calm':{'calm','peaceful','serene','mindful','relaxing','meditating','harmony','tranquil','zen','yoga'},
    'happy':{'happy','joyful','upbeat','cheerful','positive','smiling','laughter','outgoing','fun','music','joy'},
    'tropical':{'tropical','island','beach','sunny','coconut','palm','vacation','paradise','summer'}
}

# %%
setting_dict = {
    'culinary': {'kitchen','restaurant','bakery','food truck','farmers market','buffet','cafeteria','food court','diner','banquet hall'},
    'fruits':{'orchard','grove','vineyard','farm','fruit stand','fruit tree','meadow','garden','smoothie'},
    'aquatic':{'ocean floor','ocean','sea','river','lake','boat','submarine','harbor','sunken city','beach','coastline','fishing village','coral reef','yacht','lighthouse','tide'},
    'rich':{'mansion','luxury hotel','palace','art gallery','five star resort','yacht','grand hall','penthouse','villa'},
    'rugged':{'barbershop','lumberyard','garage','whiskey bar','military barracks','cigar lounge','forge'},
    'soft':{'boudoir','ballet studio','terrace','veranda','goddess','muse','fairy'},
    'old':{'monastery','bookshop','library','temple','ruins','antique shop','relic','attic'},
    'exotic':{'foreign country','foreign land','strange land','desert oasis','shrine','adventure','incense'},
    'urban':{'city','metropolis','street','subway','alley','skyscraper','city street'},
    'home':{'home','bedroom','sofa','bed','nursery'},
    'fantasy':{'Hogwarts','castle','apothecary','tavern','dragon\'s lair','alchemy lab','ritual chamber','wizard\'s study'},
    'dystopian':{'wasteland','ruins','city ruins'},
    'action':{'battle','fight','crash','battlefield','wartime','battle arena',},
    'romance':{'kiss','heart','date','dance','romantic dinner','wedding altar','falling in love'},
    'nature':{'forest','mountain','prairie','field','woods','wilderness','outdoors','grove','woodland','glade','marshland','hilltop'},
    'clean':{'water','hospital corridor','spa suite','new home','linen closet','laundry room'},
    'sci-fi':{'spaceship','observatory','asteroid colony','space station','biotech lab',},
    'intense':{'red carpet','award show','photoshoot','cocktail bar','music festival'},
    'calm':{'farewell party','sunset','meditation room','porch','tea room'},
    'happy':{'party','celebration','concert','festival','birthday party'},
    'tropical':{'island','beach','vacation','paradise','bungalow','beach hut'}
}

# %% [markdown]
# # Generating training set

# %%
dataset = []
dataset_chatml = []

for _ in range(102):
    base = random.choice(base_prompts)                                  # base prompt
    theme1 = random.choice(list(theme_dict.keys()))                     # sample themes
    theme2 = random.choice(list(theme_dict.keys()))
    descriptor = random.choice(list(theme_dict[theme1]))                # sample a descriptor
    article = 'an' if descriptor[0] in {'a','e','i','o','u'} else 'a'
    setting = random.choice(list(setting_dict[theme2]))                 # sample a setting
    context = f'{article} {descriptor} {setting}'                       # construct context
    prompt = base.format(context)                                       # construct prompt
    # sample 5 perfume notes associated to each of the prompt's themes
    recs_theme1 = random.sample(theme_scent_dict[theme1],5)
    recs_theme2 = random.sample(theme_scent_dict[theme2],5)
    recommendations = recs_theme1 + recs_theme2
    str_rec_notes = ', '.join(set.union({note[0] for note in recs_theme1},
                                   {note[1] for note in recs_theme1},
                                   {note[0] for note in recs_theme2},
                                   {note[1] for note in recs_theme2}))
    str_recs = f'Such a perfume would probably contain notes of {str_rec_notes}.'
    dataset.append({'instruction':prompt, 'response': recommendations})
    dataset_chatml.append({'messages': [{'role':'user','content':prompt}, {'role':'assistant','content':str_recs}]})

# %%
random.choice(dataset)
# Out:
# {'instruction': 'What would a perfume inspired by a rebel bed smell like?',
#  'response': [('hair pomade', 'urban'),
#   ('blood', 'weird'),
#   ('wine lees', 'alcoholic'),
#   ('goldwasser', 'alcoholic'),
#   ('ammonia', 'urban'),
#   ('pretzel', 'sweets and gourmand smells'),
#   ('quenepa', 'citrus smells'),
#   ('aldehydes', 'clean'),
#   ('accord eudora®', 'clean'),
#   ('litsea cubeba', 'citrus smells')]}

# %%
output_file = "training_data.jsonl"
output_chatml = 'training_data_chatml.jsonl'

with open(output_file, "w", encoding="latin-1") as f:
    for example in dataset:
        json.dump(example, f)
        f.write("\n")

with open(output_chatml, "w", encoding="latin-1") as f:
    for example in dataset_chatml:
        json.dump(example, f)
        f.write("\n")

# %% [markdown]
# # Generating CPT data

# %%
cpt_data = []

# %%
# Add data of each note group and their descriptions
notes_df2 = pd.read_csv('notes.csv',index_col=0)
notes_df2 = notes_df2[ notes_df2['note_group'] != 'uncategorized' ]
note_groups = notes_df2.drop_duplicates(subset=['note_group','group_description'],ignore_index=True)
note_groups = note_groups[['note_group','group_description']]

for index,row in note_groups.iterrows():
    group = row['note_group']
    description = row['group_description']
    entry = f'Note Group: {group} -- {description}'
    cpt_data.append(entry)

# %%
# Add data for perfume occasions and fragrance families from FindAScent
entry = """Title: {}
Text: {}"""

def add_entry(title, text):
    full_entry = entry.format(title,text)
    cpt_data.append(full_entry)

title = 'Adventurous Fragrances:'
add_entry(title,"""Adventurous fragrances are crafted to capture the essence of exploration and the thrill of the unknown. Ideal for the bold and the fearless, those who seek new experiences and are not afraid to venture off the beaten path, these scents embody the excitement of discovery. They are as varied and dynamic as the adventures they inspire, from trekking through dense, mysterious jungles to scaling the heights of untouched mountains.""")
add_entry(title,"""When selecting an adventurous fragrance, think of the diverse landscapes of our planet and the myriad experiences it offers. The perfect adventurous scent is a complex concoction that evokes the sense of freedom and the exhilaration of exploration. It should combine unexpected notes to mimic the surprises that await in uncharted territories, creating a scent that is both invigorating and uniquely memorable. """)
add_entry(title,"""Adventurous fragrances often blend exotic, spicy, and woody notes, reflecting the vastness and diversity of the natural world. Key ingredients include:

Exotic Fruits: Mango, Papaya, and Passion Fruit offer a burst of tropical sweetness.
Spices: Cardamom, Pepper, and Saffron add depth and warmth, mirroring the spice of adventure.
Woody Notes: Cedar, Sandalwood, and Oud provide a sturdy foundation, reminiscent of ancient forests and untouched lands.
Leather: Evokes the ruggedness of the journey, adding a sense of endurance and strength.
Incense: Introduces a mystical, spiritual dimension to the fragrance, hinting at the deeper discoveries of travel.

Adventurous Fragrances""")

title = 'Autumn Fragrances'
add_entry(title,"""As the vibrant greens of summer give way to the rich, warm hues of autumn, the air fills with the crisp scent of falling leaves, the earthy fragrance of damp forests, and the comforting aroma of spices being gently simmered. Autumn fragrances capture the essence of this season of transformation, offering scents that are as rich and layered as the tapestry of colors that adorn the trees. Ideal for brisk walks through leaf-strewn paths, cozy evenings by the fire, and every moment in between, autumn fragrances are a celebration of warmth, comfort, and the bittersweet beauty of change.""")
add_entry(title,"""When selecting an autumn fragrance, imagine wrapping yourself in a soft, warm blanket on a cool day. The perfect autumn scent is as comforting as a cup of spiced cider in your hands — deep, enveloping, and complex, with an undercurrent of warmth that soothes and uplifts. It should evoke the richness of the season, embodying the perfect balance of warmth, spice, and earthiness that defines autumn. """)
add_entry(title,"""Autumn fragrances favor notes that are warm, spicy, and woody, reflecting the season's cozy and introspective mood. Look for ingredients like:

Amber: Provides a warm, resinous base that adds depth and coziness.
Patchouli: Offers a rich, earthy depth that grounds the fragrance.
Vetiver: Known for its dry, woody character, vetiver adds a layer of complexity.
Spices: Cinnamon, Clove, and Nutmeg contribute warmth and a sense of comfort.
Apple: Crisp and slightly sweet, apple adds a touch of autumnal freshness.""")
add_entry(title,"""Further enriching the tapestry of autumn scents are woody and leather notes, which introduce a sense of enduring strength and refined elegance:

Cedar and Sandalwood: These woody notes provide a sturdy backbone, reminiscent of forests preparing for winter, offering a solid, grounding presence that complements the season's change.
Leather: Evokes the softness of worn-in boots and jackets, adding a refined, luxurious touch to the fragrance palette, suggesting comfort and reliability amidst the cooling weather.""")

title = 'Business and professional fragrances'
add_entry(title,"""Business and professional fragrances epitomize the aura of confidence, sophistication, and success. Designed for the modern workplace and formal events, these scents convey a sense of authority and competence, making them ideal for anyone looking to make a lasting impression in a professional setting. Reflecting the polished elegance of a well-tailored suit or the crispness of a freshly pressed blouse, these fragrances are as indispensable as a portfolio or briefcase in the realm of business.""")
add_entry(title,"""When selecting a business and professional fragrance, consider the ambiance of a high-stakes board meeting, the focused calm of an executive office, or the bustling energy of a creative workspace. The perfect professional scent is refined and understated, a subtle signature that enhances one's presence without overpowering. It should embody the balance between assertiveness and approachability, leaving a trail of admiration and respect. """)
add_entry(title,"""""")
add_entry(title,"""Business and professional fragrances often feature notes that are clean, fresh, and refined, reflecting the polished demeanor of the wearer. These ingredients combine to create a fragrance that is both memorable and discreet, projecting an image of professionalism and attention to detail. Key ingredients include:

Citrus Notes: Lemon, Bergamot, and Grapefruit offer a refreshing, crisp opening.
Green Notes: Grass and Green Leaves evoke a sense of freshness and vitality.
Woody Notes: Cedar, Sandalwood, and Vetiver provide a solid, reassuring foundation.
Spices: Black Pepper, Cardamom, and Ginger add a dash of sophistication and warmth.
Herbal Notes: Rosemary, Lavender, and Sage lend a clean, professional touch.
Floral Accents: Jasmine, Iris, and Rose offer a subtle, elegant complexity.""")

title = 'Casual Fragrances'
add_entry(title,"""Casual fragrances embody the spirit of laid-back sophistication, offering scents that blend seamlessly with everyday moments. These fragrances are the olfactory backdrop to life's simple pleasures: a weekend brunch, a leisurely stroll through the city, or a spontaneous gathering with friends. Ideal for those who prefer subtlety over statement, casual fragrances are understated yet distinctive, enhancing one's personal style with an air of relaxed confidence.""")
add_entry(title,"""When selecting a casual fragrance, imagine the comfort of your favorite cotton shirt, the refreshing shade of a breezy afternoon, and the liberating feeling of having nowhere to be but exactly where you are. The perfect casual scent is like a second skin — versatile, easy to wear, and always appropriate. It should complement your natural aura without overpowering it, embodying the essence of effortless chic. """)
add_entry(title,"""Daytime fragrances often lean towards the fresher, brighter side of the olfactory spectrum. Citrus notes are quintessential, offering an immediate burst of energy and optimism. Look for ingredients like

Bergamot: A sophisticated citrus with a unique floral and spicy edge, perfect for adding a refined touch.
Lemon and Lime: These zesty notes inject a sense of freshness and clarity, embodying the essence of a sunlit day.
Grapefruit: With its slightly bitter and invigorating aroma, grapefruit adds a modern twist to daytime perfumes.""")
add_entry(title,"""Floral notes also play a significant role in daytime scents, lending a natural, blooming quality that resonates with the light of day. Flowers commonly found in these compositions include:

Jasmine: Known for its intoxicatingly rich, yet delicate profile, jasmine infuses elegance and femininity.
Rose: A timeless symbol of beauty, rose adds a touch of romance and sophistication.
Lavender: Offering a clean, herbal freshness, lavender brings a calming yet invigorating quality.
""")

title = 'Evening Fragrances'
add_entry(title,"""As the sun sets and the stars take the stage, the world transforms under the veil of twilight. Evening fragrances capture the essence of this transformation, offering scents that complement the mystery, elegance, and excitement of nighttime. Ideal for dinners, parties, or any event under the moon's glow, these fragrances are your silent confidants, enhancing your aura with an air of sophistication and depth.""")
add_entry(title,"""When selecting an evening fragrance, consider rich, intoxicating compositions that linger and enchant. The perfect evening scent unfolds like a nocturnal bloom — intense, captivating, leaving a trail of allure and mystery. It should be bold yet balanced, capable of standing out in the night's embrace without overwhelming. """)
add_entry(title,"""Evening fragrances often lean towards the warmer, deeper side of the olfactory spectrum. Oriental and woody notes are staples, offering a base of warmth and complexity. Look for ingredients like:

Amber: Provides a warm, resinous base that adds depth and sensuality.
Vanilla: Its sweet, comforting warmth is irresistible and forms the heart of many evening scents.
Musk: Adds a subtle hint of animalic warmth, enhancing the fragrance's staying power and allure.
Patchouli: Known for its rich, earthy depth, patchouli adds a layer of mystique.
Sandalwood: Offers a creamy, soft woody base that is both luxurious and calming.""")
add_entry(title,"""Floral notes can also play a significant role in evening scents, lending a lush, aromatic quality that resonates with the night's depth. Flowers commonly found in these compositions include:

Tuberose: Intense and heady, tuberose infuses fragrances with opulence and seduction.
Jasmine: Its rich, indolic character is perfect for adding complexity and allure.
Rose: Adds a touch of romantic sophistication and depth.""")

title = 'Formal Fragrances'
add_entry(title,"""Formal occasions call for a fragrance that complements the gravity and sophistication of the event. Whether attending a black-tie gala, a sophisticated wedding, or any occasion where elegance is key, formal fragrances lend an air of refinement and poise. These scents are carefully crafted to enhance the wearer's presence, adding a layer of allure that's both distinguished and subtly commanding.""")
add_entry(title,"""When selecting a formal fragrance, envision the luxurious feel of velvet, the sparkle of crystal, and the hushed tones of anticipation in a grand hall. The perfect formal scent is as meticulously composed as a piece of classical music — complex, with a depth that unfolds gradually, revealing its richness over time. It should harmonize with the wearer's attire, making a statement of sophistication without overpowering the senses. """)
add_entry(title,"""Formal fragrances often feature a blend of rich, luxurious notes that evoke opulence and majesty. Key ingredients include:

Oud: Prized for its rarity and depth, oud adds a rich, woody base that's both exotic and commanding.
Iris: Known for its powdery, sophisticated scent, iris lends an elegant, refined touch.
""")
add_entry(title,"""When selecting a summer fragrance, imagine the heat of the sun on your skin, the refreshing touch of sea spray, and the sweet taste of ripe fruit. The perfect summer scent is as refreshing as a cool drink in the shade — lively, bright, and effervescent, with an undercurrent of warmth that mirrors the summer sun. It should evoke the carefree spirit of summer, embodying the season's dynamic blend of heat and freshness. """)
add_entry(title,"""Summer fragrances favor notes that are fresh, fruity, and aquatic, reflecting the season's vibrant energy and refreshing moments. Key ingredients often include:

Citrus Notes: Lemon, Orange, Bergamot, and Grapefruit offer a zesty, energizing lift, perfect for the summer heat.
Coconut: Evokes the creamy sweetness of tropical beaches, adding a sun-kissed warmth.
Sea Salt: Captures the essence of ocean breezes, adding a crisp, mineral freshness.
Watermelon: Juicy and sweet, watermelon adds a playful, refreshing layer to summer scents.
Jasmine: Its exotic, floral scent is intensified by the heat, adding depth and sensuality.""")
add_entry(title,"""Adding to the complexity and appeal of summer fragrances are green and herbal notes, which introduce a cool, refreshing contrast reminiscent of shaded gardens and crisp waters:

Basil: Offers a green, slightly spicy freshness that's both invigorating and aromatic, perfect for cutting through the summer heat.
Mint: Known for its cool, sharp clarity, mint refreshes and revitalizes, embodying the essence of a sunlit day.
Cucumber: Brings a clean, watery crispness, evoking the dewy freshness of a summer morning.

Summer Fragrances""")

title = 'Travel and vacation fragrances'
add_entry(title,"""Travel and vacation fragrances capture the exhilarating spirit of adventure and the bliss of relaxation, embodying the essence of escape to far-flung destinations or cherished holiday spots. These scents are for the wanderlust-filled moments, designed to evoke memories of sunny beaches, exotic markets, serene landscapes, and vibrant cities. Ideal for both globetrotters and dreamers, travel and vacation fragrances are your invisible passport to the world, offering a sensory journey to the places you love or long to visit.""")
add_entry(title,"""When selecting a travel and vacation fragrance, imagine the first breath of sea air as you step onto the sand, the spicy aroma of a bustling bazaar, or the fresh scent of mountain pines. The perfect travel scent is dynamic and evocative, a versatile companion that adapts to your surroundings, whether you're exploring a new city or lounging by the pool. It should be as refreshing as a cool drink on a hot day and as comforting as the feeling of sand between your toes. """)
add_entry(title,"""Travel and vacation fragrances often incorporate notes that are fresh, exotic, and uplifting, reflecting the joy and freedom of travel. Key ingredients include:

Tropical Fruits: Mango, Coconut, and Pineapple offer a taste of paradise.
Sea Salt: Captures the essence of the ocean breeze and sun-kissed skin.
Floral Notes: Tiare Flower, Hibiscus, and Frangipani evoke the beauty of island blooms.
Citrus Notes: Lime, Orange Blossom, and Bergamot add a zesty, energizing kick.
Spices: Saffron, Cinnamon, and Clove bring warmth and depth, reminiscent of exotic locales.
Aquatic Accords: Fresh and clean, mimicking the refreshing quality of water.

These ingredients blend to create fragrances that are as memorable as your travels, bringing a sense of joy and anticipation for your next journey.""")

title = 'Winter Fragrances'
add_entry(title,"""As the winter season wraps the world in its chilly embrace, the air becomes crisp, and the landscape transforms under a blanket of snow. Winter fragrances capture the essence of this serene and introspective time, offering scents that complement the season's unique beauty and stillness. Ideal for cozy evenings by the fire, festive gatherings, or bracing walks in the winter air, these fragrances are like a warm, comforting hug, enhancing your presence with depth and warmth.""")
""")
add_entry(title,"""Following the success of Cool Water, the 1990s saw a surge in the popularity of aquatic scents, with many fragrance houses introducing their own interpretations of the oceanic theme. These fragrances leveraged synthetic molecules, such as Calone, to mimic the scent of wet air, sea spray, and fresh, aquatic environments. The use of these synthetic components allowed perfumers to create scents that evoked the natural freshness of the sea, rivers, and rain, without relying on traditional floral or citrus notes.""")
add_entry(title,"""Aquatic fragrances quickly expanded beyond the realm of men's perfumery, with many women's and unisex fragrances embracing the clean, refreshing qualities of marine notes. Brands explored various aquatic nuances, from the salty freshness of sea water to the soft, serene qualities of lake and river scents, broadening the appeal of this fragrance family.""")
add_entry(title,"""Today, aquatic fragrances continue to be popular for their versatility, freshness, and ability to convey a sense of purity and rejuvenation. They are particularly favored in warmer climates and during the summer months, when the desire for light, refreshing scents is at its peak. Aquatic fragrances have also inspired a subcategory of fragrances that blend marine notes with fruity, floral, or green elements, offering a wide range of scents that capture the essence of water in all its forms.""")
add_entry(title,"""Aquatic fragrances are the essence of freshness and purity, embodying the infinite serenity and invigorating energy of water. They evoke the feeling of standing by a crashing ocean wave, the tranquility of a still lake at dawn, or the refreshing spray of a waterfall. Aquatic scents are characterized by their clean, crisp notes, which can include hints of sea salt, fresh marine accords, and the coolness of water mint. These fragrances often incorporate citrus or floral notes to add brightness and depth, creating a scent that is both refreshing and subtly complex.""")
add_entry(title,"""Daytime and Summer: Aquatic fragrances shine brightest in the daytime and during the warmer summer months. Their light and refreshing nature makes them perfect for hot weather, providing a cooling sensation that is both uplifting and energizing.""")
add_entry(title,"""Casual and Outdoor Activities: Due to their fresh and unobtrusive character, aquatic scents are ideal for casual outings, such as a day at the beach, a picnic in the park, or an outdoor sporting event. They complement the natural outdoor environment, enhancing the experience of being in open, airy spaces.""")
add_entry(title,"""Sporty and Active: Aquatic fragrances are a great match for sporty and active lifestyles. Whether you're hitting the gym, going for a run, or engaging in any physical activity, these scents offer a clean, fresh vibe that lasts through your workout.""")
add_entry(title,"""Work and Professional Settings: The crisp, clean profile of aquatic fragrances makes them suitable for the workplace. They are subtle enough to be worn in professional settings, offering a sense of freshness without being overpowering.""")
add_entry(title,"""Travel and Vacation: Aquatic scents are perfect for travel and vacation, especially to tropical or coastal destinations. They capture the spirit of adventure and the joy of exploring new places, making them a fitting choice for those who love to wander.""")
add_entry(title,"""Evening Events by the Water: While typically favored for daytime, aquatic fragrances can also be ideal for evening events held near water bodies, like a beachside dinner or a yacht party. In these settings, they blend beautifully with the natural surroundings, enhancing the night's ambiance with their oceanic notes.""")
add_entry(title,"""Aquatic fragrances, celebrated for their fresh and clean qualities, capture the essence of water in perfume form. These scents often evoke the freshness of the sea, rain, or cool mountain streams, offering a refreshing and revitalizing olfactory experience. """)
add_entry(title,"""The classic Aquatic structure typically features:

Top Notes: Marine notes and citrus elements, providing a crisp and invigorating opening that mimics the briskness of ocean air or the zest of coastal breezes.

Heart Notes: Aquatic flowers and green notes, adding a layer of freshness that enhances the water-inspired essence of the fragrance. This middle layer often includes notes like water lily, lotus, or green leaves, contributing to the scent's clean and natural character.

Base Notes: Musk, woods, and sometimes amber, giving the fragrance a foundation that grounds the aquatic freshness with a subtle warmth. These base notes ensure the scent's longevity, leaving a soft and comforting trail that balances the aquatic freshness with a touch of earthiness.""")
add_entry(title,"""
Main Components and Notes of Aquatic Fragrances
Sea Salt Accords: To mimic the scent of the oceanic air.
Citrus Notes: Such as bergamot, lemon, and grapefruit, to add freshness and brightness.
Aquatic Plants: Like seaweed or water lily, to provide a green, slightly herbal quality.
Marine Notes: Compounds that mimic the smell of sand, sea air, and wet stones.
Woods and Musks: Used in the base to provide a sense of warmth and depth, grounding the airy and fresh top notes.""")

title = 'Floral Fragrance Family'
add_entry(title,"""The Floral fragrance family is perhaps the most extensive and popular category within perfumery, embodying the essence of flower gardens, bouquets, and the natural aroma of blooming flowers. Floral scents are the heart of many perfumes, offering a wide range of fragrances from the delicate and subtle to the bold and intoxicating. This family captures the pure beauty of flowers, from the sweetness of roses and the lushness of lilies to the exotic allure of jasmine and the softness of lavender.
""")
add_entry(title,"""Floral fragrances are synonymous with femininity and romance, evoking the timeless beauty and the delicate complexity of flowers. They can range from single flower scents, known as soliflores, which highlight the aroma of a single flower, to complex floral bouquets that blend multiple floral notes to create a harmonious and multifaceted scent profile. Floral fragrances are versatile and can convey a spectrum of moods and emotions, from innocence and freshness to depth and sensuality. """)
add_entry(title,"""Floral fragrances, with their rich history and deep cultural significance, have been a cornerstone of perfumery since ancient times. In ancient civilizations, flowers played a pivotal role in religious ceremonies and personal adornment, marking the beginnings of their use in creating scents. The Egyptians, in particular, are noted for their advanced scent techniques, incorporating floral extracts such as jasmine and lily into burial rituals and daily life, showcasing the intrinsic value and symbolism flowers held within their society. This tradition of floral scents continued to evolve, particularly flourishing during the Renaissance in Europe, where the burgeoning art of perfumery saw floral essences derived from roses, violets, and other blooms become symbols of purity, beauty, and the ephemeral nature of existence.""")
add_entry(title,"""The progression of floral fragrances was markedly advanced by the Industrial Revolution, which introduced refined extraction techniques like enfleurage and distillation. These advancements enabled perfumers to more effectively capture the essence of flowers, leading to the creation of more nuanced and intricate floral compositions. The late 19th and early 20th centuries marked a golden age for perfumery, with the creation of iconic floral fragrances that continue to be celebrated. The advent of synthetic ingredients further broadened the perfumer's toolkit, allowing for the reproduction of floral scents that had been challenging to extract, and ushering in an era of innovation and creativity within the floral fragrance family.""")
add_entry(title,"""Today, the floral fragrance family remains a dominant force in the perfume industry, driven by ongoing innovations in chemistry and the globalization of the marketplace. Modern floral scents encompass a wide range, from traditional soliflores focusing on a single flower to intricate blends that recreate the scent of an entire garden. Looking forward, the industry's focus on sustainability and ethical sourcing of ingredients signals a move towards floral fragrances that not only delight the senses but are also conscientious of their environmental impact. Advances in biotechnology and green chemistry hold the promise of a new generation of floral scents that marry olfactory pleasure with ecological responsibility, ensuring the enduring appeal and relevance of floral fragrances.
""")
add_entry(title,"""Floral fragrances have the unique ability to transport the wearer to a world of beauty and serenity, reminiscent of a blooming garden in spring. They evoke feelings of love, joy, and femininity, making them a popular choice for weddings, romantic evenings, and any occasion that calls for elegance and sophistication. Floral scents are also often used to uplift the mood and create a sense of comfort and well-being.""")
add_entry(title,"""Daytime and Casual Occasions: Floral fragrances, with their bright and uplifting notes, are perfect for daytime wear. They shine in casual settings, offering a fresh and approachable aura that's as fitting for a weekend brunch as it is for a day at the office.""")
add_entry(title,"""Spring and Summer: The natural, blooming essence of floral perfumes makes them especially suitable for the warmer months of spring and summer. Their light, airy qualities resonate with the rejuvenation and vibrancy of these seasons, complementing the lighter attire and outdoor activities.""")
add_entry(title,"""Romantic Occasions: The inherent sweetness and femininity of floral scents lend themselves beautifully to romantic dates or evenings. Whether it's a bouquet of roses or the delicate whisper of jasmine, floral fragrances can encapsulate the essence of romance.""")
add_entry(title,"""Weddings and Special Events: For weddings and grand celebrations, floral fragrances offer a classic and elegant choice. They can mirror the floral arrangements and add a layer of sophistication and grace to the wearer's presence.""")
add_entry(title,"""Relaxation and Comfort: Certain floral scents, especially those with lavender or chamomile, can also be suited for moments of relaxation and comfort, providing a soothing backdrop to unwind and destress.""")
add_entry(title,"""Floral fragrances stand as the epitome of femininity and romance, embracing the broad spectrum of the floral kingdom. Renowned for their versatility and depth, these scents range from the delicate simplicity of a single flower to complex bouquets combining numerous floral notes.""")
add_entry(title,"""The classic Floral structure is often categorized as follows:

Top Notes: Light and fresh accents such as lily of the valley, peony, or rose, introducing the fragrance with a soft, inviting aroma that gently transitions into the heart of the scent.

Heart Notes: The essence of the fragrance, featuring fuller, more voluptuous floral notes such as jasmine, tuberose, or gardenia. This middle layer represents the core of the floral theme, offering richness and depth.

Base Notes: Subtle hints of musk, vanilla, or sandalwood that provide a warm, enduring foundation. These notes support and enhance the floral heart, adding complexity and ensuring the fragrance's longevity on the skin.""")
add_entry(title,"""Main Components and Notes of Floral Fragrances
Roses: Symbolic of love and beauty, rose scents are a cornerstone of Floral fragrances.
Jasmine: Known for its rich and highly fragrant aroma, adding depth and sensuality.
Lavender: Offers a fresh, clean, and slightly herbal note.
Gardenia and Tuberose: Provide rich, creamy, and intoxicating tropical floral scents.
Lilies and Orchids: Contribute exotic and diverse aromas, from spicy to soft and powdery.""")

title = 'Fresh Fragrance Family'
add_entry(title,"""The Fresh fragrance family is celebrated for its crisp, clean, and invigorating scents that evoke feelings of freshness and purity. This broad category encompasses a variety of aromatic profiles, including aquatic, citrus, green, and fruity notes, all of which share a common theme of offering a refreshing olfactory experience. Fresh fragrances are known for their versatility and appeal, making them suitable for everyday wear, especially during the warmer months when the desire for something light and uplifting is strongest.""")
add_entry(title,"""
Fresh fragrances are the epitome of revitalization and energy, designed to awaken the senses and bring a sense of cleanliness and renewal. These scents are often composed of components that mimic the natural aromas of water, air, grass, and fresh fruits, providing a wide range of options for those seeking a lively and vibrant scent. From the zesty punch of citrus fruits to the cool touch of aquatic notes, Fresh fragrances offer an escape into nature's most invigorating and rejuvenating aspects. """)
add_entry(title,"""The Fresh fragrance family, characterized by its clean, invigorating scents, represents a significant evolution in perfumery that began in the latter part of the 20th century. Drawing inspiration from the natural elements of water, air, and greenery, these fragrances evoke a sense of renewal and vitality. The introduction of aquatic notes in the 1990s, with the use of synthetic compounds like Calone, was a groundbreaking innovation, enabling perfumers to mimic the ozonic qualities of sea air and fresh rain. This new dimension of freshness brought to life scents that captured the crispness of the ocean and the refreshing cool of a breeze, marking a distinct shift from the heavier, more opulent fragrances that had previously dominated the market.""")
add_entry(title,"""In addition to aquatic notes, the Fresh family is renowned for its incorporation of green and citrus accords, which add to the overall sense of energy and cleanliness. Green notes, reminiscent of leaves and freshly cut grass, offer a sharp, natural freshness, while citrus elements, derived from fruits like lemon, bergamot, and orange, introduce a bright, zesty quality that is both uplifting and invigorating. Furthermore, this fragrance family includes scents that mimic the clean, soapy aroma of freshly laundered linens and the softness of powdery compositions, making them ideal for everyday wear and situations that call for a subtle, unassuming fragrance.""")
add_entry(title,"""Today's Fresh fragrances continue to evolve, with perfumers experimenting with new materials and blending techniques to craft even more nuanced and sophisticated fresh scents. This expansion has led to a diverse range of subcategories within the family, catering to a broad audience in search of a breath of freshness in their fragrance choices. As the industry shifts toward sustainability and the use of natural ingredients, the Fresh family is poised to benefit, promising future developments that include bioengineered and eco-friendly compounds. These innovations aim to capture the essence of freshness in a way that is both respectful to the environment and fulfilling to the wearer, ensuring the enduring popularity of Fresh fragrances in the olfactory landscape.""")
add_entry(title,"""Fresh fragrances have the power to instantly uplift and energize, making them a popular choice for daytime wear, sporty activities, or any occasion that calls for a feeling of cleanliness and vivacity. They are especially favored in the spring and summer months, providing a refreshing counterpoint to the heat and intensity of the season.""")
add_entry(title,"""Daytime Wear: Fresh fragrances are perfect for daytime use, thanks to their light and uplifting qualities. Whether it's a casual outing, a day at the office, or running errands, these scents add a clean, energetic vibe to your day.""")
add_entry(title,"""Warm Weather: In the spring and summer, when the warmth amplifies the essence of fragrances, Fresh scents truly shine. Their cool and airy notes make them ideal for hot weather, providing a refreshing sensation that can help you stay cool and collected.""")
add_entry(title,"""Sporty & Active Occasions: For those with an active lifestyle, Fresh fragrances offer a great complement to sporty activities. Whether you're heading to the gym, going for a run, or engaging in outdoor sports, these scents reinforce the feeling of freshness throughout your active pursuits.""")
add_entry(title,"""Casual Outings: Fresh fragrances align well with casual settings, where a subtle, unobtrusive scent is preferred. From weekend brunches to casual meet-ups with friends, they provide a pleasant backdrop without overwhelming the senses.""")
add_entry(title,"""Office and Professional Settings: In professional environments, where discretion in fragrance choice is often appreciated, Fresh scents serve as an excellent choice. They convey cleanliness and efficiency, making them suitable for office wear and business meetings.""")
add_entry(title,"""Travel & Vacation: Fresh fragrances capture the spirit of adventure and relaxation, making them a perfect travel companion. Whether you're exploring a new city or lounging by the beach, these scents enhance the experience with their light, carefree essence. """)
add_entry(title,"""Fresh fragrances are characterized by their light, airy, and often aquatic or citrusy notes. These scents are typically composed of:

Top Notes: Bright and zesty citrus, crisp green notes, or cool aquatic accords for an immediate burst of freshness.

Heart Notes: Light floral or herbal elements to add a subtle depth and complexity.

Base Notes: Soft musk, woods, or amber to ground the fragrance without overpowering the fresh, clean character.
""")
add_entry(title,"""
Main Components and Notes of Fresh Fragrances
Citrus Notes: Lemon, bergamot, orange, and grapefruit provide a sharp, refreshing opening.
Aquatic Notes: Marine accords that evoke the scent of sea spray and fresh rain.
Green Notes: Grass, leaves, and green herbs offer a crisp, vegetal freshness.
Fruity Notes: Light and sweet fruits, such as apple, pear, and melon, add a playful and vibrant touch.
""")

title = 'Musky Fragrance Family'
add_entry(title,"""The Musky fragrance family encompasses a broad spectrum of scents that can evoke a range of emotions and memories, thanks to their deep, warm, and enveloping nature. Initially sourced from the musk deer for its rich and long-lasting aroma, musk has been a cornerstone in the creation of perfumes for centuries. The transition to synthetic musk has allowed perfumers to capture the essence of musk's appeal without harm to any animals, resulting in a diverse array of musky scents that maintain the original allure of natural musk. These synthetic variants provide a clean, smooth base that can range from subtle whispers to bold statements, making musky fragrances a staple in both men's and women's perfumeries.""")
add_entry(title,"""Musky scents are renowned for their staying power and are often used to anchor the lighter top and heart notes of a fragrance, ensuring a lasting impression. The innate warmth and depth of musk make it an ideal candidate for blending, allowing it to harmonize with floral, citrus, woody, or spicy notes to create complex and multifaceted perfumes. This chameleon-like quality of musk enables it to enhance the presence of other scents, making them more pronounced and enduring on the skin.""")
add_entry(title,"""In the contemporary world of perfumery, musky fragrances continue to captivate wearers with their timeless appeal. Whether used sparingly for a hint of mystery or more liberally for a bold statement, musk's versatility makes it a beloved choice for any occasion. From the clean and subtle to the deep and powerful, musky perfumes offer a foundational element that is both comforting and provocative, making them an indispensable part of the fragrance world. """)
add_entry(title,"""Musky fragrances, known for their warm, sensual scent profiles, originate from the animal kingdom. Historically, musk was derived from the musk pod of the male musk deer, a highly coveted ingredient for its intoxicating aroma and purported aphrodisiac qualities. This use of musk can be traced back to ancient civilizations in India, Persia, and Rome, where it was used in perfumery, incense, and medicinal concoctions. During the Middle Ages and Renaissance, musk became a symbol of opulence and erotic allure in European courts. Its rarity and the difficulty of obtaining it made musk-based perfumes a luxury that only the nobility could afford. This period saw the incorporation of musk in everything from personal fragrances to scented gloves and linens.""")
add_entry(title,"""The turning point for musky fragrances came in the late 19th and early 20th centuries with the discovery and synthesis of musk compounds, such as musk ketone and musk xylene. These synthetic musks, developed to mimic the scent of natural musk, made the warm, sensual aroma of musky fragrances accessible to a broader audience. In contemporary perfumery, musky fragrances have evolved beyond their animalistic roots to include a wide range of scents from clean and subtle to deep and alluring. Synthetic musks play a pivotal role in modern perfumes, serving as fixatives that enhance the longevity and depth of fragrances. They are appreciated for their versatility, acting as a foundation that blends seamlessly with floral, woody, and spicy notes.""")
add_entry(title,"""The future of musky fragrances lies in the ongoing development of new synthetic musk molecules that are environmentally friendly and adhere to strict safety standards. As the perfumery industry moves towards sustainability and ethical sourcing, musky fragrances continue to captivate with their timeless appeal, now more accessible and diverse than ever. The appeal of musky fragrances endures in the 21st century, reflecting a fascination with their primal, earthy essence. As consumer preferences shift towards unique and personalized scents, musky fragrances offer a canvas for creativity, blending tradition with innovation to satisfy a wide range of olfactory tastes.""")
add_entry(title,"""Musky fragrances evoke a sense of intimacy and comfort, making them ideal for personal, close-contact settings. They are known for their skin-like quality, which makes the scent feel like a natural extension of the wearer. Favored for intimate settings and when a sensual, warm scent is desired.""")
add_entry(title,"""Evening Events: Musky fragrances, with their sensual and enveloping qualities, are perfect for evening wear. They complement the ambiance of dinner parties, nightclubs, or romantic dates, adding an element of allure and sophistication.""")
add_entry(title,"""Autumn and Winter: The warmth of musky scents makes them particularly suited for the cooler months. Their depth and persistence help to create a feeling of warmth and comfort during autumn and winter.""")
add_entry(title,"""Formal Occasions: Musky perfumes lend an air of formality and elegance, making them suitable for business events, weddings, and other formal gatherings. They provide a subtle yet powerful statement of confidence and refinement.""")
add_entry(title,"""Intimate Settings: Due to their sensuous nature, musky fragrances are ideal for intimate settings. They are known to be captivating and can enhance the personal connection in close encounters. """)
add_entry(title,"""Musky fragrances are revered for their warm, sensual, and enveloping qualities, often forming the base note of many perfumes. Originating from the natural secretions of animals like the musk deer (though now largely synthesized to protect these species), musk's complex scent profile is a cornerstone of perfumery.""")
add_entry(title,"""The classic Musky structure is nuanced, featuring:

Top Notes: Light and airy notes such as lavender, citrus, or soft floral scents introduce the fragrance, creating an inviting and clean opening. These initial notes gently lead into the more pronounced musky heart, setting a delicate stage.

Heart Notes: The essence of musk dominates the heart of these fragrances, characterized by its skin-like, warm, and deep qualities. It may be accompanied by powdery flowers like iris or rose, adding a touch of elegance and softness to the rich muskiness.

Base Notes: Anchoring the fragrance, the base notes often include amber, woods, and vanilla, which complement the musk's warmth and add depth, longevity, and a comforting finish. Elements such as patchouli, sandalwood, or oakmoss may also be present, enriching the sensual and earthy feel of the musk.""")
add_entry(title,"""Main Components and Notes of Musky Fragrances
White Musk: Offers a clean, light scent that is modern and often used in fresh fragrances.
Animalic Musk: Mimics the original musk scent with a deeper, more complex aroma.
Fruity and Floral Accords: Are frequently blended with musky notes to create a softer, more approachable scent.""")

title = 'Woody Fragrance Family'
add_entry(title,"""The Woody fragrance family embodies the essence of nature's enduring beauty, with scents that are deeply rooted in the earthy, rich aromas of the forest. Characterized by warm, dry, and earthy notes derived from woods and mosses, including sandalwood, cedar, patchouli, and vetiver, woody fragrances convey a sense of grounding, stability, and natural sophistication. They often form the base of both masculine and feminine scents, providing a sturdy foundation upon which other notes can flourish. Their versatility is unmatched, ranging from light and airy compositions adorned with fresh, green notes to deep and resonant concoctions featuring rich, smoky undertones.""")
add_entry(title,"""At the heart of perfumery, woody fragrances serve as a cornerstone, offering a broad palette of scents that capture the essence of the forest in all its forms. From the damp earthiness of the forest floor to the aromatic air of a pine-clad mountain, these fragrances evoke a world of natural wonder. They are celebrated for their enduring warmth and depth, appealing to those who seek a scent that embodies maturity, refinement, and a deep connection to the earth. Woody fragrances are not just scents; they are an olfactory journey through nature's vast landscapes, inviting wearers to explore the richness and diversity of the world around them.""")
add_entry(title,"""In the modern perfumery landscape, woody fragrances continue to evolve, blending traditional wood notes with innovative elements from other fragrance families to create complex, multifaceted scents. Perfumers are increasingly experimenting with unconventional wood sources, synthetic molecules that mimic the warmth of wood, and unexpected combinations that challenge traditional perceptions of what a woody fragrance can be. This spirit of innovation ensures that woody fragrances remain at the forefront of scent design, offering timeless classics and cutting-edge creations that continue to captivate and inspire fragrance enthusiasts around the globe. """)
add_entry(title,"""The woody fragrance family is one of the most enduring and significant categories in the world of perfumery. Characterized by warm, rich, and grounding notes, woody scents have been a foundational element in perfume compositions for centuries. Their history is intertwined with the evolution of perfumery itself, reflecting changes in culture, technology, and artistic expression.""")
add_entry(title,"""The use of woody materials in fragrances dates back to ancient civilizations. In cultures such as Egypt, Mesopotamia, and India, aromatic woods like cedar, sandalwood, and agarwood (oud) were highly valued for their scent and were often used in religious rituals, embalming practices, and personal adornment. These woods were burned as incense or infused into oils, serving both spiritual and olfactory purposes.""")
add_entry(title,"""During the classical periods of Greek and Roman societies, perfumery became more sophisticated. The Romans, in particular, were known for their lavish use of fragrances. They utilized woody notes in their balms and oils, often combining them with florals and spices to create complex scents. The trade routes of the time facilitated the exchange of exotic woods and resins, enriching the palette of perfumers.""")
add_entry(title,"""In the Middle Ages, the art of perfumery in Europe was influenced by interactions with the Middle East during the Crusades. The introduction of distillation techniques allowed for the extraction of essential oils from woods, leading to more potent and long-lasting fragrances. Sandalwood and cedar remained popular, while new materials like patchouli began to emerge.""")
add_entry(title,"""The Renaissance period saw a revival in the arts and sciences, including perfumery. Wealthy patrons commissioned bespoke scents, and woody notes were often featured prominently. The use of musk and ambergris, though animal-derived, complemented woody bases, adding depth and sensuality.""")
add_entry(title,"""The early 20th century marked a significant turning point with the creation of Chypre by François Coty in 1917. Although chypre is its own fragrance family, it heavily relies on woody notes, particularly oakmoss and patchouli, combined with citrus and floral elements. This composition paved the way for more abstract and sophisticated uses of woody accords in perfumery.""")
add_entry(title,"""The development of synthetic aromatic compounds expanded the possibilities for perfumers. Molecules like vetiveryl acetate and Iso E Super allowed for new interpretations of woody scents, offering consistency and intensity that natural materials sometimes lacked. These innovations led to the creation of iconic fragrances that centered around woody themes, such as Guerlain's Vetiver (1959) and Dior's Eau Sauvage (1966).""")
add_entry(title,"""In recent decades, woody fragrances have gained immense popularity across both men's and women's perfumery. The unisex appeal of woody scents aligns with modern trends toward gender-neutral fragrances. Ingredients like cedarwood, sandalwood, vetiver, and patchouli are used extensively, often combined with spicy, aromatic, or even gourmand notes.

The resurgence of oud in Western perfumery is a notable development. Once primarily used in Middle Eastern fragrances, oud has become a coveted material in luxury perfumes, adding a rich and complex woody character.""")
add_entry(title,"""Woody fragrances evoke the tranquility and majesty of the forest, bringing a sense of calm and connectedness to nature. They are well-suited for everyday wear as well as special occasions, offering a timeless elegance and understated sophistication.""")
add_entry(title,"""Evening and Formal Occasions: The depth and sophistication of woody scents also make them suitable for evening events and formal gatherings. The rich, enduring base notes provide a luxurious and refined backdrop, enhancing the wearer's presence in more dressed-up settings.""")
add_entry(title,"""Autumn and Winter: The inherent warmth and richness of woody fragrances align beautifully with the cooler months of autumn and winter. They envelop the wearer in a comforting warmth, reminiscent of a cozy fire or a walk through a forest laden with fallen leaves.""")
add_entry(title,"""Professional and Business Environments: Woody fragrances convey a sense of reliability and strength, making them a fitting choice for business meetings and professional environments. Their understated elegance supports an image of confidence and competence.""")
add_entry(title,"""Travel and Adventure: For those with a love for exploration and adventure, woody fragrances evoke the spirit of the wild and the excitement of discovery. They are a perfect companion for travel, offering a sense of connection to the vast, uncharted corners of the world. """)
add_entry(title,"""Woody fragrances ground themselves in the rich and earthy essence of the forest. Known for their deep, enduring warmth, these scents draw inspiration from nature's foundational elements—trees, roots, and resins.""")
add_entry(title,"""The classic Woody fragrance structure incorporates:

Top Notes: Often fresh or herbal, to introduce the fragrance with a natural and inviting appeal. Ingredients like bergamot, lavender, and citrus provide a light introduction that gently transitions into the heart of the scent.

Heart Notes: At the core of Woody fragrances lie the rich, full-bodied scents of various woods. Cedar, sandalwood, and pine create a complex and layered aroma that's both comforting and sophisticated. These heart notes may also be complemented by spices or florals to add depth and diversity.

Base Notes: The foundation of Woody scents is characterized by the most enduring and resonant woody notes, such as vetiver, oakmoss, and amberwood. These base notes provide a lasting depth and warmth, often enriched with resinous or earthy elements like amber and patchouli for a truly profound finish.""")
add_entry(title,"""Main Components and Notes of Woody Fragrances
Sandalwood: Known for its smooth, creamy, and rich scent.
Cedar: Offers a clean, sharp woody aroma.
Patchouli: Adds a deep, earthy quality with a slightly sweet undertone.
Vetiver: Provides a complex, slightly smoky or leathery green scent.""")

# %%
findascent_notes = pd.read_csv('findascent_note_descriptions.csv',index_col=0)

for index, row in findascent_notes.iterrows():
    name = row['note']
    desc = row['desc']
    entry = f'Note: {name} -- {desc}'
    cpt_data.append(entry)

print(findascent_notes.head())
# Out:
#            note                                               desc
# 0      Absinthe  Absinthe, often characterized by its green hue...
# 1  Acacia Honey  Acacia Honey, often derived from the blossoms ...
# 2    Acai Berry  Acai Berry, derived from the Acai palm tree na...
# 3   Acajou Wood  Acajou Wood, also known as African Mahogany (K...
# 4        Adoxal  Adoxal is a synthetic compound widely utilized...

# %%
gpt_descs = pd.read_csv('perfume_descriptions.csv',usecols=['description'])
gpt_descs = list(gpt_descs['description'].values)
gpt_descs_creative = pd.read_csv('perfume_descriptions_creative.csv',usecols=['description'])
gpt_descs_creative = list(gpt_descs_creative['description'].values)
cpt_data += random.sample(gpt_descs,50)
cpt_data += random.sample(gpt_descs_creative,50)

# %%
cpt_training = 'cpt_perfume.jsonl'

with open(cpt_training, "w", encoding="latin-1") as f:
    for example in cpt_data:
        json.dump(example, f)
        f.write("\n")
